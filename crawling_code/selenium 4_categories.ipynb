# %%
# !pip install selenium
# !pip install BeautifulSoup4
# !pip install chromedriver-autoinstaller
# Out:
# Requirement already satisfied: selenium in c:\users\sojos\anaconda3\lib\site-packages (4.7.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\sojos\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\sojos\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\sojos\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\sojos\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\sojos\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\sojos\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\sojos\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\sojos\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\sojos\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sojos\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\users\sojos\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in c:\users\sojos\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\sojos\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\sojos\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\sojos\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\sojos\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: BeautifulSoup4 in c:\users\sojos\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sojos\anaconda3\lib\site-packages (from BeautifulSoup4) (2.3.1)
# Requirement already satisfied: chromedriver-autoinstaller in c:\users\sojos\anaconda3\lib\site-packages (0.4.0)

# %%
from selenium import webdriver
import chromedriver_autoinstaller
import time
import pandas as pd
import numpy as np
from selenium.webdriver.common.by import By
import re
pd.options.display.max_columns = None
pd.options.display.max_rows = 355

chrome_ver = chromedriver_autoinstaller.get_chrome_version().split('.')[0]
chrome_ver
# Out:
# '108'

# %%
try:
    crawler = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe')
except:
    crawler = chromedriver_autoinstaller.install(True)
    crawler = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe')
crawler.implicitly_wait(10)
crawling_url = 'https://search.shopping.naver.com/search/category/100002371?catId=50014240&origQuery&pagingIndex=1&pagingSize=40&productSet=total&query&sort=rel&timestamp=&viewType=list'
crawler.get(crawling_url)
# Out:
# C:\Users\sojos\AppData\Local\Temp\ipykernel_11244\1382095078.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   crawler = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe')

# %%
cat1 = crawler.find_element('xpath', '//*[@id="__next"]/div/div[2]/div/div[2]/div[1]/div[1]/div[2]/div/h4/a/span[1]').text
cat2 = crawler.find_element('xpath', '//*[@id="__next"]/div/div[2]/div/div[2]/div[1]/div[1]/div[2]/div/h4/a/span[2]').text
cat3 = crawler.find_element('xpath', '//*[@id="__next"]/div/div[2]/div/div[2]/div[1]/div[1]/div[2]/div/h4/a/span[3]').text
cat4 = crawler.find_element('xpath', '//*[@id="__next"]/div/div[2]/div/div[2]/div[1]/div[1]/div[2]/div/h4/a/span[4]').text
cat1, cat2, cat3, cat4
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11244\2352639041.py in <module>
#       2 cat2 = crawler.find_element('xpath', '//*[@id="__next"]/div/div[2]/div/div[2]/div[1]/div[1]/div[2]/div/h4/a/span[2]').text
#       3 cat3 = crawler.find_element('xpath', '//*[@id="__next"]/div/div[2]/div/div[2]/div[1]/div[1]/div[2]/div/h4/a/span[3]').text
# ----> 4 cat4 = crawler.find_element('xpath', '//*[@id="__next"]/div/div[2]/div/div[2]/div[1]/div[1]/div[2]/div/h4/a/span[4]').text
#       5 cat1, cat2, cat3, cat4
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     859             value = '[name="%s"]' % value
#     860
# --> 861         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     862
#     863     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     442         response = self.command_executor.execute(driver_command, params)
#     443         if response:
# --> 444             self.error_handler.check_response(response)
#     445             response["value"] = self._unwrap_value(response.get("value", None))
#     446             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     247                 alert_text = value["alert"].get("text")
#     248             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/div/div[2]/div/div[2]/div[1]/div[1]/div[2]/div/h4/a/span[4]"}
#   (Session info: chrome=108.0.5359.125)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0039E563]
# 	(No symbol) [0x00327FC1]
# 	(No symbol) [0x0021D04D]
# 	(No symbol) [0x0024C0B0]
# 	(No symbol) [0x0024C22B]
# 	(No symbol) [0x0027E612]
# 	(No symbol) [0x002685D4]
# 	(No symbol) [0x0027C9EB]
# 	(No symbol) [0x00268386]
# 	(No symbol) [0x0024163C]
# 	(No symbol) [0x0024269D]
# 	GetHandleVerifier [0x00639B82+2658722]
# 	GetHandleVerifier [0x0062CB84+2605476]
# 	GetHandleVerifier [0x0044825A+620666]
# 	GetHandleVerifier [0x00446E80+615584]
# 	(No symbol) [0x003305EC]
# 	(No symbol) [0x00335958]
# 	(No symbol) [0x00335A45]
# 	(No symbol) [0x0034050B]
# 	BaseThreadInitThunk [0x75B77D69+25]
# 	RtlInitializeExceptionChain [0x770EBB9B+107]
# 	RtlClearBits [0x770EBB1F+191]

# %%
cat_list = [f'//*[@id="__next"]/div/div[2]/div/div[2]/div[1]/div[1]/div[2]/div/ul/li[{i}]/a/span' for i in range(1, int(cat4)+1)]

# %%
data = []

# %%
for cat in cat_list[3:1]:
    crawler.find_element('xpath', cat).click()
    cat_now = crawler.find_element('xpath', cat).text
    time.sleep(1)
    
    print(cat_now)
    
    url = crawler.current_url
    cat_code = re.findall('/[0-9]{9}', url)[0][1:]
    cat_id = re.findall('=[0-9]{8}', url)[0][1:]

    for i in range(1, 9999):
                
        crawler.get(f'https://search.shopping.naver.com/search/category/{cat_code}?catId={cat_id}&origQuery&pagingIndex={i}&pagingSize=20&productSet=total&query&sort=rel&timestamp=&viewType=list')
        print(f'now {cat_now}:{i} page')
        
        while True:
            time.sleep(1)
            bh = crawler.execute_script('return document.body.scrollHeight')

            crawler.execute_script('window.scrollTo(0, document.body.scrollHeight)')

            ah = crawler.execute_script('return document.body.scrollHeight')

            if ah == bh:
                break
                time.sleep(0.8)
                
            bh = ah
            crawler.execute_script('window.scrollTo(document.body.scrollHeight, 0)')
        
        time.sleep(2)
        infos = crawler.find_elements(By.CSS_SELECTOR, '.basicList_info_area__TWvzp')
        for info in infos:
            name = info.find_element(By.CSS_SELECTOR, '.basicList_title__VfX3c > a').text
            price = info.find_element(By.CSS_SELECTOR, 'div.basicList_info_area__TWvzp > div.basicList_price_area__K7DDT > strong > span > span.price_num__S2p_v').text
            data.append([name, cat2, cat3, cat_now, price])
        
        print(f'size of df: {len(data)}\n')
# Out:
# 피자
# now 피자:1 page
# size of df: 3770
#
# now 피자:2 page
# size of df: 3796
#
# now 피자:3 page
# size of df: 3822
#
# now 피자:4 page
# size of df: 3848
#
# now 피자:5 page
# size of df: 3874
#
# now 피자:6 page
# size of df: 3900
#
# now 피자:7 page
# size of df: 3926
#
# now 피자:8 page
# size of df: 3952
#
# now 피자:9 page
# size of df: 3978
#
# now 피자:10 page
# size of df: 4004
#
# now 피자:11 page
# size of df: 4030
#
# now 피자:12 page
# size of df: 4056
#
# now 피자:13 page
# size of df: 4082
#
# now 피자:14 page
# size of df: 4108
#
# now 피자:15 page
# size of df: 4134
#
# now 피자:16 page
# size of df: 4160
#
# now 피자:17 page
# size of df: 4184
#
# now 피자:18 page
# size of df: 4204
#
# now 피자:19 page
# size of df: 4224
#
# now 피자:20 page
# size of df: 4244
#
# now 피자:21 page
# size of df: 4264
#
# now 피자:22 page
# size of df: 4284
#
# now 피자:23 page
# size of df: 4304
#
# now 피자:24 page
# size of df: 4324
#
# now 피자:25 page
# size of df: 4344
#
# now 피자:26 page
# size of df: 4349
#
# now 피자:27 page
# size of df: 4354
#
# now 피자:28 page
# size of df: 4359
#
# now 피자:29 page
# size of df: 4364
#
# now 피자:30 page
# size of df: 4369
#
# now 피자:31 page
# size of df: 4374
#
# now 피자:32 page
# size of df: 4379
#
# now 피자:33 page
# size of df: 4384
#
# now 피자:34 page
# size of df: 4389
#
# now 피자:35 page
# size of df: 4394
#
# now 피자:36 page
# size of df: 4399
#
# now 피자:37 page
# size of df: 4404
#
# now 피자:38 page
# size of df: 4424
#
# now 피자:39 page
# size of df: 4429
#
# now 피자:40 page
# size of df: 4434
#
# now 피자:41 page
# size of df: 4439
#
# now 피자:42 page
# size of df: 4444
#
# now 피자:43 page
# size of df: 4449
#
# now 피자:44 page
# size of df: 4454
#
# now 피자:45 page
# size of df: 4459
#
# now 피자:46 page
# size of df: 4464
#
# now 피자:47 page
# size of df: 4469
#
# now 피자:48 page
# size of df: 4474
#
# now 피자:49 page
# size of df: 4479
#
# now 피자:50 page
# size of df: 4484
#
# now 피자:51 page
# size of df: 4489
#
# now 피자:52 page
# size of df: 4494
#
# now 피자:53 page
# size of df: 4499
#
# now 피자:54 page
# size of df: 4504
#
# now 피자:55 page
# size of df: 4509
#
# now 피자:56 page
# size of df: 4514
#
# now 피자:57 page
# size of df: 4519
#
# now 피자:58 page
# size of df: 4524
#
# now 피자:59 page
# size of df: 4529
#
# now 피자:60 page
# size of df: 4534
#
# now 피자:61 page
# size of df: 4539
#
# now 피자:62 page
# size of df: 4544
#
# now 피자:63 page
# size of df: 4549
#
# now 피자:64 page
# size of df: 4554
#
# now 피자:65 page
# size of df: 4559
#
# now 피자:66 page
# size of df: 4564
#
# now 피자:67 page
# size of df: 4569
#
# now 피자:68 page
# size of df: 4574
#
# now 피자:69 page
# size of df: 4579
#
# now 피자:70 page
# size of df: 4584
#
# now 피자:71 page
# size of df: 4589
#
# now 피자:72 page
# size of df: 4594
#
# now 피자:73 page
# size of df: 4599
#
# now 피자:74 page
# size of df: 4604
#
# now 피자:75 page
# size of df: 4609
#
# now 피자:76 page
# size of df: 4614
#
# now 피자:77 page
# size of df: 4619
#
# now 피자:78 page
# size of df: 4624
#
# now 피자:79 page
# size of df: 4629
#
# now 피자:80 page
# size of df: 4634
#
# now 피자:81 page
# size of df: 4639
#
# now 피자:82 page
# size of df: 4644
#
# now 피자:83 page
# size of df: 4649
#
# now 피자:84 page
# size of df: 4654
#
# now 피자:85 page
# size of df: 4659
#
# now 피자:86 page
# size of df: 4664
#
# now 피자:87 page
# size of df: 4669
#
# now 피자:88 page
# size of df: 4674
#
# now 피자:89 page
# size of df: 4679
#
# now 피자:90 page
# size of df: 4699
#
# now 피자:91 page
# size of df: 4719
#
# now 피자:92 page
# size of df: 4739
#
# now 피자:93 page
# size of df: 4759
#
# now 피자:94 page
# size of df: 4779
#
# now 피자:95 page
# size of df: 4799
#
# now 피자:96 page
# size of df: 4819
#
# now 피자:97 page
# size of df: 4839
#
# now 피자:98 page
# size of df: 4859
#
# now 피자:99 page
# size of df: 4879
#
# now 피자:100 page
# size of df: 4899
#
# now 피자:101 page
# size of df: 4919
#
# now 피자:102 page
# size of df: 4939
#
# now 피자:103 page
# size of df: 4959
#
# now 피자:104 page
# size of df: 4979
#
# now 피자:105 page
# size of df: 4999
#
# now 피자:106 page
# size of df: 5019
#
# now 피자:107 page
# size of df: 5039
#
# now 피자:108 page
# size of df: 5059
#
# now 피자:109 page
# size of df: 5079
#
# now 피자:110 page
# size of df: 5099
#
# now 피자:111 page
# size of df: 5104
#
# now 피자:112 page
# size of df: 5109
#
# now 피자:113 page
# size of df: 5114
#
# now 피자:114 page
# size of df: 5119
#
# now 피자:115 page
# size of df: 5124
#
# now 피자:116 page
# size of df: 5129
#
# now 피자:117 page
# size of df: 5134
#
# now 피자:118 page
# size of df: 5139
#
# now 피자:119 page
# size of df: 5144
#
# now 피자:120 page
# size of df: 5149
#
# now 피자:121 page
# size of df: 5154
#
# now 피자:122 page
# size of df: 5159
#
# now 피자:123 page
# size of df: 5164
#
# now 피자:124 page
# size of df: 5169
#
# now 피자:125 page
# size of df: 5174
#
# now 피자:126 page
# size of df: 5179
#
# now 피자:127 page
# size of df: 5184
#
# now 피자:128 page
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11244\1272188871.py in <module>
#      31
#      32         time.sleep(2)
# ---> 33         infos = crawler.find_elements(By.CSS_SELECTOR, '.basicList_info_area__TWvzp')
#      34         for info in infos:
#      35             name = info.find_element(By.CSS_SELECTOR, '.basicList_title__VfX3c > a').text
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#     890         # Return empty list if driver returns null
#     891         # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 892         return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#     893
#     894     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     440                 params["sessionId"] = self.session_id
#     441
# --> 442         response = self.command_executor.execute(driver_command, params)
#     443         if response:
#     444             self.error_handler.check_response(response)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     292         data = utils.dump_json(params)
#     293         url = f"{self._url}{path}"
# --> 294         return self._request(command_info[0], url, body=data)
#     295
#     296     def _request(self, method, url, body=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     314
#     315         if self.keep_alive:
# --> 316             response = self._conn.request(method, url, body=body, headers=headers)
#     317             statuscode = response.status
#     318         else:
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374             response = conn.urlopen(method, url, **kw)
#     375         else:
# --> 376             response = conn.urlopen(method, u.request_uri, **kw)
#     377
#     378         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(columns=['title', 'cat1', 'cat2', 'cat3', 'price'], data=data)

# %%
df['cat3'].unique()
# Out:
# array(['핫도그', '햄버거', '피자'], dtype=object)

# %%
df.to_csv(f'핫도그_햄버거_피자.csv')

# %%
df.shape
# Out:
# (5184, 5)
