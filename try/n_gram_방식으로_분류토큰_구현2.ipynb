# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 37.7 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.6/465.6 KB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.8/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from JPype1>=0.7.0->konlpy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->JPype1>=0.7.0->konlpy) (3.0.9)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('menu_concated_v1.3')
df = df.dropna()

# %%
menu = df['menu'].tolist()
menu = list(set(menu))

# %%
from konlpy.tag import Okt
from tqdm import tqdm
okt = Okt()

# %%
menu_token = [okt.morphs(i) for i in tqdm(menu)]
# Out:
# 100%|██████████| 51437/51437 [01:08<00:00, 751.43it/s]

# %%
len(menu_token)
# Out:
# 51437

# %%
menu_token = [j for i in menu_token for j in i]
len(menu_token), menu_token[:10]
# Out:
# ['한우', '차돌', '골뱅이', '무침과', '순', '살', '치킨', '우리', '고구마', '코코넛']

# %%
def to_ngrams(words, n):
  ngrams = []
  for b in range(0, len(words) - n + 1):
      ngrams.append(words[b:b+n])
  return ngrams

# %%
menu_ngrams = []

# %%
menu_ngrams = menu_token
menu_ngrams += [to_ngrams(i, 2) for i in menu]
menu_ngrams += [to_ngrams(i, 3) for i in menu]
menu_ngrams += [to_ngrams(i, 4) for i in menu]
menu_ngrams += [to_ngrams(i, 5) for i in menu]
menu_ngrams += [to_ngrams(i, 6) for i in menu]

# %%
menu_ngrams = [j for i in menu_ngrams for j in i]

# %%
len(menu_ngrams)
# Out:
# 1176675

# %%
menu_count = {}

for i in menu_token:
  if i not in menu_count:
    menu_count[i] = 1
  else:
    menu_count[i] += 1

# %%
menu_count['즙']
# Out:
# 13

# %%
items = menu_count.items()
sorted_items = sorted(items, key=lambda x: x[1], reverse=True) # 빈도 내림차순 정렬
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-7df250fd7244> in <module>
#       1 items = menu_count.items()
#       2 sorted_items = sorted(items, key=lambda x: x[1], reverse=True) # 빈도 내림차순 정렬
# ----> 3 sorted_items['뼈']
#
# TypeError: list indices must be integers or slices, not str

# %%
# 스탑워즈의 반대
go_words = ['빵', '회', '잼', '티', '젓', '팥', '식', '캔', '뼈', '떡', '즙', '팩', '꿀', '술', '굴', '국', '밥', '탕', '면', '컵']

# %%
sorted_items_rank = [v for v, c in sorted_items if c >= 150 and len(v) != 1] # 150개 이상 중복 + 길이가 2 이상
sorted_items_rank = sorted(sorted_items_rank, key=lambda x: len(x), reverse=True) # 길이 내림차순 정렬렬

for i in go_words:
  if menu_count[i] >= 50:
    sorted_items_rank.append(i)

sorted_items_rank
# Out:
# ['아메리카노',
#  '스테이크',
#  '샌드위치',
#  '후라이드',
#  '포테이토',
#  '블루베리',
#  '김치찌개',
#  '불고기',
#  '샐러드',
#  '파스타',
#  '돈까스',
#  '떡볶이',
#  '볶음밥',
#  '소고기',
#  '스무디',
#  '스페셜',
#  '오징어',
#  '베이컨',
#  '비빔밥',
#  '삼겹살',
#  '요거트',
#  '토마토',
#  '고구마',
#  '탕수육',
#  '쭈꾸미',
#  '아이스',
#  '칼국수',
#  '바닐라',
#  '쌀국수',
#  '바나나',
#  '돈가스',
#  '도시락',
#  '토스트',
#  '오렌지',
#  '카라멜',
#  '케이크',
#  '치즈',
#  '치킨',
#  '세트',
#  '추가',
#  '라떼',
#  '볶음',
#  '새우',
#  '크림',
#  '튀김',
#  '피자',
#  '구이',
#  '정식',
#  '양념',
#  '매운',
#  '해물',
#  '초코',
#  '김치',
#  '갈비',
#  '전골',
#  '한우',
#  '밀크',
#  '돼지',
#  '우동',
#  '짬뽕',
#  '이드',
#  '감자',
#  '레몬',
#  '김밥',
#  '딸기',
#  '야채',
#  '사리',
#  '매콤',
#  '커피',
#  '고기',
#  '만두',
#  '간장',
#  '마늘',
#  '허니',
#  '버섯',
#  '마리',
#  '무침',
#  '갈릭',
#  '오리',
#  '초밥',
#  '철판',
#  '삼겹',
#  '수제',
#  '블랙',
#  '족발',
#  '변경',
#  '전복',
#  '참치',
#  '라면',
#  '소스',
#  '망고',
#  '등심',
#  '카레',
#  '자몽',
#  '낙지',
#  '보쌈',
#  '오뎅',
#  '버터',
#  '두부',
#  '과일',
#  '닭발',
#  '고추',
#  '숯불',
#  '프라',
#  '버거',
#  '미니',
#  '꼬치',
#  '연어',
#  '베리',
#  '림프',
#  '주스',
#  '빙수',
#  '어묵',
#  '국수',
#  '더블',
#  '차돌',
#  '국밥',
#  '곱창',
#  '메뉴',
#  '계란',
#  '리얼',
#  '코스',
#  '맥주',
#  '민트',
#  '골드',
#  '칠리',
#  '순대',
#  '국물',
#  '빵',
#  '회',
#  '티',
#  '팥',
#  '식',
#  '뼈',
#  '떡',
#  '팩',
#  '꿀',
#  '굴',
#  '국',
#  '밥',
#  '탕',
#  '면',
#  '컵']

# %%
menu_cluster = {}

for food_token in tqdm(sorted_items_rank):
  for food_name in menu:
    if food_name not in menu_cluster: # 이미 분류된 메뉴는 건들지 않음

      # 메뉴명이 토큰명보다 길면서 동시에 토큰명으로 끝나는 메뉴를 토큰 카테고리로 분류 
      if len(food_token) <= len(food_name) and food_name[-len(food_token):] == food_token:
        menu_cluster[food_name] = food_token
# Out:
# 100%|██████████| 143/143 [00:04<00:00, 30.13it/s]

# %%
menu_cluster
# Out:
# {'돈까스아메리카노': '아메리카노',
#  '커피콩빵아메리카노': '아메리카노',
#  '베이글아메리카노': '아메리카노',
#  '크로와상샌드위치아메리카노': '아메리카노',
#  '몬테크레스토조각아메리카노': '아메리카노',
#  '딥블랙아메리카노': '아메리카노',
#  '샌드위치하프아메리카노': '아메리카노',
#  '진한아메리카노': '아메리카노',
#  '크레마아메리카노': '아메리카노',
#  '햄치즈아메리카노': '아메리카노',
#  '카야토스트아메리카노': '아메리카노',
#  '리터아메리카노': '아메리카노',
#  '벌꿀아메리카노': '아메리카노',
#  '아몬드아메리카노': '아메리카노',
#  '치킨깔조네아메리카노': '아메리카노',
#  '밤만주아메리카노': '아메리카노',
#  '오리지널핫도그아메리카노': '아메리카노',
#  '폼나는민트아메리카노': '아메리카노',
#  '바닐라아메리카노': '아메리카노',
#  '흑당아메리카노': '아메리카노',
#  '아메리카노더치아메리카노': '아메리카노',
#  '헤즐럿아메리카노': '아메리카노',
#  '라바짜아메리카노': '아메리카노',
#  '씨앗인절미토스트아메리카노': '아메리카노',
#  '유기농아메리카노': '아메리카노',
#  '헤이즐넛아메리카노': '아메리카노',
#  '에스프레소아메리카노': '아메리카노',
#  '오늘의샌드위치아메리카노': '아메리카노',
#  '앗아메리카노': '아메리카노',
#  '사케아메리카노': '아메리카노',
#  '프리미엄블렌드아메리카노': '아메리카노',
#  '수제돈까스아메리카노': '아메리카노',
#  '생크림아메리카노': '아메리카노',
#  '잉글리쉬머핀아메리카노': '아메리카노',
#  '꿀호떡아메리카노': '아메리카노',
#  '스톰아메리카노': '아메리카노',
#  '큐브더치아메리카노': '아메리카노',
#  '오늘의더치아메리카노': '아메리카노',
#  '스페셜티아메리카노': '아메리카노',
#  '도넛아메리카노': '아메리카노',
#  '김치볶음밥아메리카노': '아메리카노',
#  '눈꽃아메리카노': '아메리카노',
#  '헤이즐너아메리카노': '아메리카노',
#  '허니부쉬아메리카노': '아메리카노',
#  '카페아메리카노': '아메리카노',
#  '아이스아메리카노': '아메리카노',
#  '롱블랙아메리카노': '아메리카노',
#  '토스트아메리카노': '아메리카노',
#  '유자아메리카노': '아메리카노',
#  '식사후아메리카노': '아메리카노',
#  '프리미엄블랜드아메리카노': '아메리카노',
#  '테이크아웃아메리카노': '아메리카노',
#  '연한아메리카노': '아메리카노',
#  '생아메리카노': '아메리카노',
#  '닭가슴살샌드위치아메리카노': '아메리카노',
#  '스파클링아메리카노': '아메리카노',
#  '프리미엄아메리카노': '아메리카노',
#  '어반브런치아메리카노': '아메리카노',
#  '김치라이스아메리카노': '아메리카노',
#  '아이스진한아메리카노': '아메리카노',
#  '핸드드립아메리카노': '아메리카노',
#  '폼나는콜드브루아메리카노': '아메리카노',
#  '수제등심아메리카노': '아메리카노',
#  '밀크폼아메리카노': '아메리카노',
#  '코코넛아메리카노': '아메리카노',
#  '카무아메리카노': '아메리카노',
#  '대용량아메리카노': '아메리카노',
#  '헤이즐럿아메리카노': '아메리카노',
#  '스노우아메리카노': '아메리카노',
#  '비엔나아메리카노': '아메리카노',
#  '디카페인아메리카노': '아메리카노',
#  '시그니처아메리카노': '아메리카노',
#  '엘살바도르핀카몬테레이센트로아메리카노': '아메리카노',
#  '카페아디자오아메리카노': '아메리카노',
#  '아인슈페너아메리카노': '아메리카노',
#  '미트칠리핫도그아메리카노': '아메리카노',
#  '새우볶음밥아메리카노': '아메리카노',
#  '모든샌드위치아메리카노': '아메리카노',
#  '순수한아메리카노': '아메리카노',
#  '팬케잌아메리카노': '아메리카노',
#  '게이샤아메리카노': '아메리카노',
#  '모닝토스트아메리카노': '아메리카노',
#  '조각케이크아메리카노': '아메리카노',
#  '크릴아메리카노': '아메리카노',
#  '폴바셋아메리카노': '아메리카노',
#  '꿀아메리카노': '아메리카노',
#  '콜라겐아메리카노': '아메리카노',
#  '카레아메리카노': '아메리카노',
#  '샌드위치아메리카노': '아메리카노',
#  '디카페인카페아메리카노': '아메리카노',
#  '치아바타샌드위치아메리카노': '아메리카노',
#  '크로플아메리카노': '아메리카노',
#  '프레즐아메리카노': '아메리카노',
#  '치아바샌드위치아메리카노': '아메리카노',
#  '자몽아메리카노': '아메리카노',
#  '엘리스샌드위치아메리카노': '아메리카노',
#  '크림아메리카노': '아메리카노',
#  '핫아메리카노': '아메리카노',
#  '햄듬뿍샌드위치아메리카노': '아메리카노',
#  '바다소금아메리카노': '아메리카노',
#  '큐브아메리카노': '아메리카노',
#  '더치아메리카노': '아메리카노',
#  '허니아메리카노': '아메리카노',
#  '허니브레드아메리카노': '아메리카노',
#  '홈메이드샌드위치아메리카노': '아메리카노',
#  '핫도그아메리카노': '아메리카노',
#  '아이스연한아메리카노': '아메리카노',
#  '콜드브루아메리카노': '아메리카노',
#  '깔루아아메리카노': '아메리카노',
#  '리필아메리카노': '아메리카노',
#  '룽고아메리카노': '아메리카노',
#  '치즈아메리카노': '아메리카노',
#  '수퍼사이즈아메리카노': '아메리카노',
#  '싱글아메리카노': '아메리카노',
#  '잉글리쉬머핀샌드위치아메리카노': '아메리카노',
#  '아메리카노': '아메리카노',
#  '월송아메리카노': '아메리카노',
#  '아이스카페아메리카노': '아메리카노',
#  '아메리카노얼그레이아메리카노': '아메리카노',
#  '헤이즐아메리카노': '아메리카노',
#  '메가아메리카노': '아메리카노',
#  '헤즐넛아메리카노': '아메리카노',
#  '시나몬아메리카노': '아메리카노',
#  '등심모듬스테이크': '스테이크',
#  '찹스스테이크': '스테이크',
#  '치즈함박스테이크': '스테이크',
#  '크런치큐브스테이크': '스테이크',
#  '등심스테이크': '스테이크',
#  '토마호크스테이크': '스테이크',
#  '블랙앵거스채끝스테이크': '스테이크',
#  '그릴치킨스테이크': '스테이크',
#  '핑거스테이크': '스테이크',
#  '눈꽃치즈함박스테이크': '스테이크',
#  '살치스테이크': '스테이크',
#  '허브치킨스테이크': '스테이크',
#  '청춘국물떡볶이함박스테이크': '스테이크',
#  '비프떡갈비스테이크': '스테이크',
#  '소고기등심팬스테이크': '스테이크',
#  '통베이컨스테이크': '스테이크',
#  '포크스테이크': '스테이크',
#  '청양트러플크림햄버거스테이크': '스테이크',
#  '허브립아이스테이크': '스테이크',
#  '바딜란쇠고기안심스테이크': '스테이크',
#  '청정호주산부채살스테이크': '스테이크',
#  '비프찹스테이크': '스테이크',
#  '한우안심부채살스테이크': '스테이크',
#  '본갈비살스테이크': '스테이크',
#  '브뤼셀스프라우트토네이도채끝스테이크': '스테이크',
#  '된장크림목살스테이크': '스테이크',
#  '치킨콤보스테이크': '스테이크',
#  '시즐링화이타샐러드스테이크': '스테이크',
#  '스톤부챗살스테이크': '스테이크',
#  '생갈비살찹스테이크': '스테이크',
#  '연어스테이크': '스테이크',
#  '한우스테이크': '스테이크',
#  '크림허브치킨쉬림프스테이크': '스테이크',
#  '채끝등심스테이크': '스테이크',
#  '화덕목살스테이크': '스테이크',
#  '목살치킨스테이크': '스테이크',
#  '블랙앵거스스테이크': '스테이크',
#  '스톤스테이크': '스테이크',
#  '프리미엄스테이크': '스테이크',
#  '햄스테이크': '스테이크',
#  '치즈블라썸스테이크': '스테이크',
#  '흑돼지목살스테이크': '스테이크',
#  '직화그릴스테이크': '스테이크',
#  '머쉬룸페퍼크림스테이크': '스테이크',
#  '블랙앵거스트러플스테이크': '스테이크',
#  '살치살스테이크': '스테이크',
#  '더블치즈함박스테이크': '스테이크',
#  '뉴욕등심스테이크': '스테이크',
#  '돈마호크스테이크': '스테이크',
#  '매운치즈함박스테이크': '스테이크',
#  '부채살스테이크': '스테이크',
#  '엘본스테이크': '스테이크',
#  '직화스테이크': '스테이크',
#  '살치살팬스테이크': '스테이크',
#  '스타쉐프시그니처블랙앵거스스테이크': '스테이크',
#  '허브크러스트양갈비스테이크': '스테이크',
#  '맵닭스테이크': '스테이크',
#  '골든큐브스테이크': '스테이크',
#  '구아카몰비프스테이크': '스테이크',
#  '비프치킨스테이크': '스테이크',
#  '한우안심찹스테이크': '스테이크',
#  '최상급한우티본스테이크': '스테이크',
#  '통삼겹스테이크': '스테이크',
#  '눈꽃치즈큐브스테이크': '스테이크',
#  '부처스스테이크': '스테이크',
#  '한우본스테이크': '스테이크',
#  '얌스톤안심스테이크': '스테이크',
#  '참숯에구운최상급숙성한우채끝등심스테이크': '스테이크',
#  '찹스테이크': '스테이크',
#  '램스테이크': '스테이크',
#  '점심특선통갈비살스테이크': '스테이크',
#  '소고기등심찹스테이크': '스테이크',
#  '목살팬스테이크': '스테이크',
#  '목살스테이크': '스테이크',
#  '화이타스테이크': '스테이크',
#  '포크콤보스테이크': '스테이크',
#  '돼지목살갈비스테이크': '스테이크',
#  '비프목살스테이크': '스테이크',
#  '청춘그릴스테이크': '스테이크',
#  '챂스테이크': '스테이크',
#  '에멘탈갈릭텐더로인스테이크': '스테이크',
#  '와규스테이크': '스테이크',
#  '최상급한우암소스테이크': '스테이크',
#  '수비드고메비프스테이크': '스테이크',
#  '치즈스테이크': '스테이크',
#  '스페셜램스테이크': '스테이크',
#  '참숯에구운최상급립아이스테이크': '스테이크',
#  '메로스테이크': '스테이크',
#  '직화포크스테이크': '스테이크',
#  '더블햄버거스테이크': '스테이크',
#  '한우안심스테이크': '스테이크',
#  '현대옥스테이크': '스테이크',
#  '브라운함박스테이크': '스테이크',
#  '두부고구마스테이크': '스테이크',
#  '피렌체스테이크': '스테이크',
#  '두부야채스테이크': '스테이크',
#  '어린이함박스테이크': '스테이크',
#  '하와이안스테이크': '스테이크',
#  '포터하우스스테이크': '스테이크',
#  '페파안심스테이크': '스테이크',
#  '서로인스테이크': '스테이크',
#  '오늘스테이크': '스테이크',
#  '까르보함박스테이크': '스테이크',
#  '함박스테이크': '스테이크',
#  '목살찹스테이크': '스테이크',
#  '본인립아이스테이크': '스테이크',
#  '농어스테이크': '스테이크',
#  '수비드치킨스테이크': '스테이크',
#  '건조숙성한우본스테이크': '스테이크',
#  '비프갈비살스테이크': '스테이크',
#  '수비드목살스테이크': '스테이크',
#  '양송이크림함박스테이크': '스테이크',
#  '포크찹스테이크': '스테이크',
#  '숙성통목살스테이크': '스테이크',
#  '한우채끝스테이크': '스테이크',
#  '모듬스테이크': '스테이크',
#  '생선스테이크': '스테이크',
#  '철판함박스테이크': '스테이크',
#  '떡갈비함박스테이크': '스테이크',
#  '삼겹스테이크': '스테이크',
#  '숙성채끝스테이크': '스테이크',
#  '올인원수제함박스테이크': '스테이크',
#  '에그함박스테이크': '스테이크',
#  '수비드통삼겹스테이크': '스테이크',
#  '갈릭허그스테이크': '스테이크',
#  '흑마늘목살찹스테이크': '스테이크',
#  '엠파이어스테이크': '스테이크',
#  '대구스테이크': '스테이크',
#  '아웃백스페셜갈릭서로인스테이크': '스테이크',
#  '뉴욕스트립스테이크': '스테이크',
#  '호주산고마블링최상급와규꽃등심스테이크': '스테이크',
#  '호주산부채살스테이크': '스테이크',
#  '삼치스테이크': '스테이크',
#  '철판더블함박스테이크': '스테이크',
#  '양갈비스테이크': '스테이크',
#  '참숯에구운안심스테이크': '스테이크',
#  '동경함박스테이크': '스테이크',
#  '두부스테이크': '스테이크',
#  '짐붐바스테이크': '스테이크',
#  '한우등심부채살스테이크': '스테이크',
#  '샬리아핀스테이크': '스테이크',
#  '점심특선와규등심스테이크': '스테이크',
#  '코리안찹스테이크': '스테이크',
#  '닭안심스테이크': '스테이크',
#  '숙주함박스테이크': '스테이크',
#  '채끝살스테이크': '스테이크',
#  '필리치즈스테이크': '스테이크',
#  '소세지함박스테이크': '스테이크',
#  '심플스테이크': '스테이크',
#  '더블포크스테이크': '스테이크',
#  '크림함박스테이크': '스테이크',
#  '스테이크': '스테이크',
#  '소고기찹스테이크': '스테이크',
#  '수비드포크스테이크': '스테이크',
#  '햄버거스테이크': '스테이크',
#  '티본스테이크': '스테이크',
#  '특본모듬스테이크': '스테이크',
#  '리코타스테이크': '스테이크',
#  '점심특선와규함박스테이크': '스테이크',
#  '채끝스테이크': '스테이크',
#  '더블치즈스테이크': '스테이크',
#  '카르네아사다스테이크': '스테이크',
#  '큐브철판스테이크': '스테이크',
#  '오리가슴살스테이크': '스테이크',
#  '흑돼지프렌치렉스테이크': '스테이크',
#  '수비드조리살치살스테이크': '스테이크',
#  '갈릭마블스테이크': '스테이크',
#  '양갈비살스테이크': '스테이크',
#  '샘스테이크': '스테이크',
#  '수비드스테이크': '스테이크',
#  '블루베리그릴스테이크': '스테이크',
#  '스타셰프시그니처블랙앵거스스테이크': '스테이크',
#  '매운함박스테이크': '스테이크',
#  '와규눈꽃스테이크': '스테이크',
#  '불갈비찹스테이크': '스테이크',
#  '레드와인찹스테이크': '스테이크',
#  '윗등심스테이크': '스테이크',
#  '치폴레스테이크': '스테이크',
#  '안심스테이크': '스테이크',
#  '소고기큐브스테이크': '스테이크',
#  '빕스뉴욕스테이크': '스테이크',
#  '비프콤보스테이크': '스테이크',
#  '까르보큐브스테이크': '스테이크',
#  '수비드이베리코스테이크': '스테이크',
#  '고고함박스테이크': '스테이크',
#  '상하이찹스테이크': '스테이크',
#  '소고기스테이크': '스테이크',
#  '단호박치즈함박스테이크': '스테이크',
#  '포크바베큐스테이크': '스테이크',
#  '트러플함박스테이크': '스테이크',
#  '불갈비그릴스테이크': '스테이크',
#  '허니크런치스테이크': '스테이크',
#  '이탈리아토마토햄버거스테이크': '스테이크',
#  '안심찹스테이크': '스테이크',
#  '닭다리살스테이크': '스테이크',
#  '뉴욕스타일꽃등심스테이크': '스테이크',
#  '버섯그라탕을얹은안심스테이크': '스테이크',
#  '이베리코항정살스테이크': '스테이크',
#  '한우등심스테이크': '스테이크',
#  '로제함박스테이크': '스테이크',
#  '소고기채끝스테이크': '스테이크',
#  '블랙앵거스안심스테이크': '스테이크',
#  '참숯목살스테이크': '스테이크',
#  '불고기스테이크': '스테이크',
#  '립아이스테이크': '스테이크',
#  '부채살팬스테이크': '스테이크',
#  '수제치즈함박스테이크': '스테이크',
#  '소안심찹스테이크': '스테이크',
#  '제스티그릴드스테이크': '스테이크',
#  '블랙알리오스테이크': '스테이크',
#  '한우찹스테이크': '스테이크',
#  '블루치즈안심스테이크': '스테이크',
#  '갈릭포크스테이크': '스테이크',
#  '치즈찹스테이크': '스테이크',
#  '프라임등급립아이스테이크': '스테이크',
#  '스타셰프트러플바질직화스테이크': '스테이크',
#  '꿀대구스테이크': '스테이크',
#  '통목살스테이크': '스테이크',
#  '수제햄버거스테이크': '스테이크',
#  '이베리코스테이크': '스테이크',
#  '한우등심철판스테이크': '스테이크',
#  '데미함박스테이크': '스테이크',
#  '갈릭스테이크': '스테이크',
#  '등급한우채끝등심스테이크': '스테이크',
#  '바이킹스테이크': '스테이크',
#  '꽃등심스테이크': '스테이크',
#  '토시스테이크': '스테이크',
#  '블랙앵거스큐브비프스테이크': '스테이크',
#  '수비드삼겹스테이크': '스테이크',
#  '큐브스테이크': '스테이크',
#  '한우채끝등심스테이크': '스테이크',
#  '블랙타이거슈림프직화스테이크': '스테이크',
#  '뉴욕찹스테이크': '스테이크',
#  '위클리스테이크': '스테이크',
#  '눈꽃치즈스테이크': '스테이크',
#  '된장목살스테이크': '스테이크',
#  '얌스톤꽃등심스테이크': '스테이크',
#  '부채스테이크': '스테이크',
#  '갈릭페퍼스테이크': '스테이크',
#  '드라이에이지드립아이스테이크': '스테이크',
#  '오븐치킨스테이크': '스테이크',
#  '갈릭그릴스테이크': '스테이크',
#  '페퍼스테이크': '스테이크',
#  '앵거스살치살스테이크': '스테이크',
#  '타워버거스테이크': '스테이크',
#  '뉴욕스테이크': '스테이크',
#  '폭찹스테이크': '스테이크',
#  '치킨스테이크': '스테이크',
#  '폭립스테이크': '스테이크',
#  '더블스테이크': '스테이크',
#  '팬치즈목살찹스테이크': '스테이크',
#  '수제함박스테이크': '스테이크',
#  '신길함박스테이크': '스테이크',
#  '냉면스톤스테이크': '스테이크',
#  '플랫아이언스테이크': '스테이크',
#  '본스테이크': '스테이크',
#  '항정살스테이크': '스테이크',
#  '더블치즈티본스테이크': '스테이크',
#  '런치리코타스테이크': '스테이크',
#  '닭가슴살스테이크': '스테이크',
#  '시리얼칠리크랩블랙앵거스스테이크': '스테이크',
#  '주문시채끝스테이크': '스테이크',
#  '차돌목살스테이크': '스테이크',
#  '점심특선부채살스테이크': '스테이크',
#  '베짱이함박스테이크': '스테이크',
#  '비프스테이크': '스테이크',
#  '슈퍼골든목살스테이크': '스테이크',
#  '스페셜폭립스테이크': '스테이크',
#  '클럽샌드위치': '샌드위치',
#  '베이컨에그샌드위치': '샌드위치',
#  '수제샌드위치': '샌드위치',
#  '치킨바질샌드위치': '샌드위치',
#  '에그아보카도샌드위치': '샌드위치',
#  '에그코울슬로샌드위치': '샌드위치',
#  '크림샐러드베이글샌드위치': '샌드위치',
#  '불고기베이글샌드위치': '샌드위치',
#  '참치치즈샌드위치': '샌드위치',
#  '베이컨칠리샌드위치': '샌드위치',
#  '에그마요치킨칠리샌드위치': '샌드위치',
#  '호밀연어샌드위치': '샌드위치',
#  '반곡통통샌드위치': '샌드위치',
#  '할라피뇨스테이크바게트샌드위치': '샌드위치',
#  '대만샌드위치': '샌드위치',
#  '비프불고기샌드위치': '샌드위치',
#  '에그햄샌드위치': '샌드위치',
#  '크루아상샌드위치': '샌드위치',
#  '필리치즈스테이크샌드위치': '샌드위치',
#  '햄치즈계란샌드위치': '샌드위치',
#  '베이컨메쉬포테이토샌드위치': '샌드위치',
#  '리코타샌드위치': '샌드위치',
#  '커피미니샌드위치': '샌드위치',
#  '에그샌드위치': '샌드위치',
#  '치즈불고기베이글샌드위치': '샌드위치',
#  '크림치즈샌드위치': '샌드위치',
#  '치킨아몬드샌드위치': '샌드위치',
#  '힘치즈샌드위치': '샌드위치',
#  '너답다샌드위치': '샌드위치',
#  '쉬림프퀴노아오픈샌드위치': '샌드위치',
#  '그릴샌드위치': '샌드위치',
#  '연어샌드위치': '샌드위치',
#  '바질리코타샌드위치': '샌드위치',
#  '대만식샌드위치': '샌드위치',
#  '돈가츠샌드위치': '샌드위치',
#  '바질페스토통밀치아바타샌드위치': '샌드위치',
#  '시그니쳐샌드위치': '샌드위치',
#  '크로크무슈샌드위치': '샌드위치',
#  '악마의초코샌드위치': '샌드위치',
#  '스파이시크래미샌드위치': '샌드위치',
#  '머슈룸치킨샌드위치': '샌드위치',
#  '치즈핫치킨베이글샌드위치': '샌드위치',
#  '치킨살사랩샌드위치': '샌드위치',
#  '치즈샌드위치': '샌드위치',
#  '햄잭치즈샌드위치': '샌드위치',
#  '아보아보샌드위치': '샌드위치',
#  '캘리포니아비프샌드위치': '샌드위치',
#  '햄치즈그릴드샌드위치': '샌드위치',
#  '뉴샌드위치': '샌드위치',
#  '치킨칠리샌드위치': '샌드위치',
#  '와사비게살크루아상샌드위치': '샌드위치',
#  '데리야끼치킨샌드위치': '샌드위치',
#  '아보카도페페로치노오픈샌드위치': '샌드위치',
#  '치아바타불고기샌드위치': '샌드위치',
#  '에그쉬림프샌드위치': '샌드위치',
#  '참치에그샌드위치': '샌드위치',
#  '후레쉬샌드위치': '샌드위치',
#  '멜팅치즈샌드위치': '샌드위치',
#  '랍스터쉬림프샌드위치': '샌드위치',
#  '에그샐러드샌드위치': '샌드위치',
#  '엘리스샌드위치': '샌드위치',
#  '트라디시옹샌드위치': '샌드위치',
#  '아보카도베이컨샌드위치': '샌드위치',
#  '에그듬뿍샌드위치': '샌드위치',
#  '베리레드라즈베리샌드위치': '샌드위치',
#  '스모크브리켓샌드위치': '샌드위치',
#  '치아바타치킨샌드위치': '샌드위치',
#  '비프앤머쉬룸샌드위치': '샌드위치',
#  '등심돈카츠샌드위치': '샌드위치',
#  '카야샌드위치': '샌드위치',
#  '삼각샌드위치': '샌드위치',
#  '베이컨에그마요샌드위치': '샌드위치',
#  '에그베이컨샌드위치': '샌드위치',
#  '샐러드샌드위치': '샌드위치',
#  '에그치즈베이글샌드위치': '샌드위치',
#  '치아바타샌드위치': '샌드위치',
#  '치킨스파이시샌드위치': '샌드위치',
#  '핫치킨로스트샌드위치': '샌드위치',
#  '치킨샌드위치': '샌드위치',
#  '루벤샌드위치': '샌드위치',
#  '그라브락스샌드위치': '샌드위치',
#  '토마토모짜렐라샌드위치': '샌드위치',
#  '과일에그샌드위치': '샌드위치',
#  '몬테크리스토샌드위치': '샌드위치',
#  '치킨페스토샌드위치': '샌드위치',
#  '올베럴샌드위치': '샌드위치',
#  '햄앤치즈샌드위치': '샌드위치',
#  '스파이시치킨샌드위치': '샌드위치',
#  '제육치즈샌드위치': '샌드위치',
#  '불고기치즈에그샌드위치': '샌드위치',
#  '게살샌드위치': '샌드위치',
#  '아보카도샌드위치': '샌드위치',
#  '햄치즈샌드위치': '샌드위치',
#  '머핀샌드위치': '샌드위치',
#  '불고기어니언샌드위치': '샌드위치',
#  '누텔라바나나샌드위치': '샌드위치',
#  '베지테리언샌드위치': '샌드위치',
#  '아보카도쉬림프오픈샌드위치': '샌드위치',
#  '훈제폴드포크샌드위치': '샌드위치',
#  '진샌드위치': '샌드위치',
#  '딸기대만샌드위치': '샌드위치',
#  '비프샌드위치': '샌드위치',
#  '크랜베리치킨샌드위치': '샌드위치',
#  '잠봉뵈르샌드위치': '샌드위치',
#  '메쉬포테이토더블치즈샌드위치': '샌드위치',
#  '튜나샌드위치': '샌드위치',
#  '아보홀릭샌드위치': '샌드위치',
#  '오늘의샌드위치': '샌드위치',
#  '와사비게살샌드위치': '샌드위치',
#  '피자베이글샌드위치': '샌드위치',
#  '참치마요샌드위치': '샌드위치',
#  '닭가슴살치즈에그샌드위치': '샌드위치',
#  '명란감자크루아상샌드위치': '샌드위치',
#  '치즈베이컨베이글샌드위치': '샌드위치',
#  '베이컨치즈에그샌드위치': '샌드위치',
#  '크로와상샌드위치': '샌드위치',
#  '케이준치킨샌드위치': '샌드위치',
#  '불고기샌드위치': '샌드위치',
#  '햄애그마요샌드위치': '샌드위치',
#  '핫도그샌드위치': '샌드위치',
#  '콤보샌드위치': '샌드위치',
#  '쉬림프카츠샌드위치': '샌드위치',
#  '아스파라거스수란오픈샌드위치': '샌드위치',
#  '제육치즈에그샌드위치': '샌드위치',
#  '칠리소시지바게트샌드위치': '샌드위치',
#  '갈릭베이컨샌드위치': '샌드위치',
#  '아보카도오픈샌드위치': '샌드위치',
#  '아메리카노콤보샌드위치': '샌드위치',
#  '에그햄치즈샌드위치': '샌드위치',
#  '루꼴라플로슈토오픈샌드위치': '샌드위치',
#  '고구마샌드위치': '샌드위치',
#  '랍스터샌드위치': '샌드위치',
#  '치킨로스트샌드위치': '샌드위치',
#  '루안바오샌드위치': '샌드위치',
#  '과카몰리오픈샌드위치': '샌드위치',
#  '불고기치즈그릴드샌드위치': '샌드위치',
#  '웰빙샌드위치': '샌드위치',
#  '클래식햄에그샌드위치': '샌드위치',
#  '땅콩버터바나나샌드위치': '샌드위치',
#  '프리미엄크래미샌드위치': '샌드위치',
#  '렐란디샌드위치': '샌드위치',
#  '프라한오픈샌드위치': '샌드위치',
#  '크랩아보카도샌드위치': '샌드위치',
#  '칠리새우샌드위치': '샌드위치',
#  '로제치킨밸런스샌드위치': '샌드위치',
#  '로스트비프샌드위치': '샌드위치',
#  '함박미니버거샌드위치': '샌드위치',
#  '치즈스테이크샌드위치': '샌드위치',
#  '아메리카노샌드위치': '샌드위치',
#  '호밀빵샌드위치': '샌드위치',
#  '플레인샌드위치': '샌드위치',
#  '베이컨올리브샌드위치': '샌드위치',
#  '햄치즈참지샌드위치': '샌드위치',
#  '단호박샌드위치': '샌드위치',
#  '소불고기샌드위치': '샌드위치',
#  '햄샌드위치': '샌드위치',
#  '땅콩대만샌드위치': '샌드위치',
#  '오리지날햄샌드위치': '샌드위치',
#  '닭가슴살샌드위치': '샌드위치',
#  '토마토카프레제샌드위치': '샌드위치',
#  '쉬림프오픈샌드위치': '샌드위치',
#  '샤워크림치킨칠리샌드위치': '샌드위치',
#  '비엘티샌드위치': '샌드위치',
#  '과콰몰리닭가슴살샌드위치': '샌드위치',
#  '크림새우샌드위치': '샌드위치',
#  '살라미모짜렐라샌드위치': '샌드위치',
#  '아메리칸햄치즈샌드위치': '샌드위치',
#  '투고샌드위치': '샌드위치',
#  '크로와상치즈샌드위치': '샌드위치',
#  '누야샌드위치': '샌드위치',
#  '레어샌드위치': '샌드위치',
#  '후레쉬모짜렐라샌드위치': '샌드위치',
#  '에그마요샌드위치': '샌드위치',
#  '치아바샌드위치': '샌드위치',
#  '샌드위치': '샌드위치',
#  '미니샌드위치': '샌드위치',
#  '그릴드닭가슴살샌드위치': '샌드위치',
#  '모듬버섯샌드위치': '샌드위치',
#  '계란샌드위치': '샌드위치',
#  '쏘치쏘치샌드위치': '샌드위치',
#  '그릴드샌드위치': '샌드위치',
#  '아라비아따샌드위치': '샌드위치',
#  '딸기잼에그샌드위치': '샌드위치',
#  '리코타치즈샌드위치': '샌드위치',
#  '폴드머쉬룸바베큐샌드위치': '샌드위치',
#  '크로아상샌드위치': '샌드위치',
#  '나수아즈튜나엔그클럽샌드위치': '샌드위치',
#  '치킨데리야끼샌드위치': '샌드위치',
#  '모닝샌드위치': '샌드위치',
#  '치킨클럽샌드위치': '샌드위치',
#  '햄치즈에그샌드위치': '샌드위치',
#  '달커스페셜샌드위치': '샌드위치',
#  '치킨까르보나라샌드위치': '샌드위치',
#  '연어아보카도샌드위치': '샌드위치',
#  '패스트라미샌드위치': '샌드위치',
#  '파머스샌드위치': '샌드위치',
#  '스파이시쉬림프샌드위치': '샌드위치',
#  '크라상샌드위치': '샌드위치',
#  '크랜베리허니에그샌드위치': '샌드위치',
#  '크랩와사비샌드위치': '샌드위치',
#  '부드러운허무스쑥치아바타샌드위치': '샌드위치',
#  '파니니샌드위치': '샌드위치',
#  '오리지널햄샌드위치': '샌드위치',
#  '미스터에그샌드위치': '샌드위치',
#  '홈메이드샌드위치': '샌드위치',
#  '포테이토에그샌드위치': '샌드위치',
#  '리코타치킨샌드위치': '샌드위치',
#  '토마토치킨샌드위치': '샌드위치',
#  '베이글샌드위치': '샌드위치',
#  '클래식클럽샌드위치': '샌드위치',
#  '하몽햄아보카도샌드위치': '샌드위치',
#  '아메리카노에그포테이토샌드위치': '샌드위치',
#  '잉글리쉬머핀샌드위치': '샌드위치',
#  '크랩밋샌드위치': '샌드위치',
#  '치킨샤워크림샌드위치': '샌드위치',
#  '깔끔한튜나샌드위치': '샌드위치',
#  '라구페퍼로니샌드위치': '샌드위치',
#  '핫바베큐치킨샌드위치': '샌드위치',
#  '불고기치즈샌드위치': '샌드위치',
#  '에크포테이토샌드위치': '샌드위치',
#  '햄모짜렐라샌드위치': '샌드위치',
#  '불고기치즈오픈샌드위치': '샌드위치',
#  '아보카도와훈제연어를곁들인오픈스타일샌드위치': '샌드위치',
#  '감자샐러드샌드위치': '샌드위치',
#  '베이컨치즈샌드위치': '샌드위치',
#  '치킨텐더샌드위치': '샌드위치',
#  '머쉬룸베이글샌드위치': '샌드위치',
#  '에그샐러드오픈샌드위치': '샌드위치',
#  '데리야끼바베큐샌드위치': '샌드위치',
#  '햄포테이토샐러드샌드위치': '샌드위치',
#  '바질페스토클럽샌드위치': '샌드위치',
#  '햄에그샌드위치': '샌드위치',
#  '베이컨더블치즈샌드위치': '샌드위치',
#  '쇠고기등심커틀렛샌드위치': '샌드위치',
#  '옛날사라다샌드위치': '샌드위치',
#  '에그포테이토샌드위치': '샌드위치',
#  '그릴페스토햄치즈샌드위치': '샌드위치',
#  '베이컨아보카드샌드위치': '샌드위치',
#  '햄치즈크림베이글샌드위치': '샌드위치',
#  '햄치즈참치샌드위치': '샌드위치',
#  '수제애플망고샌드위치': '샌드위치',
#  '연어베이글샌드위치': '샌드위치',
#  '라즈베리샌드위치': '샌드위치',
#  '그릴햄치즈샌드위치': '샌드위치',
#  '스파이시치킨반미샌드위치': '샌드위치',
#  '햄듬뿍샌드위치': '샌드위치',
#  '햄치즈대만샌드위치': '샌드위치',
#  '단호박에그샌드위치': '샌드위치',
#  '클럽하우스샌드위치': '샌드위치',
#  '참치샌드위치': '샌드위치',
#  '초코샌드위치': '샌드위치',
#  '뿔레미엘샌드위치': '샌드위치',
#  '크리스피후라이드': '후라이드',
#  '멕시핀후라이드': '후라이드',
#  '후라이드': '후라이드',
#  '원숯불양념후라이드': '후라이드',
#  '핫마요후라이드': '후라이드',
#  '안심후라이드': '후라이드',
#  '바삭담백한후라이드': '후라이드',
#  '치킨샤브레구운후라이드': '후라이드',
#  '땡초갈릭후라이드': '후라이드',
#  '치킨샤브레구운양념후라이드': '후라이드',
#  '킹프라운후라이드': '후라이드',
#  '바삭후라이드': '후라이드',
#  '양념매운양념치킨후라이드': '후라이드',
#  '버터갈릭후라이드': '후라이드',
#  '날개후라이드': '후라이드',
#  '모래집후라이드': '후라이드',
#  '웰덤후라이드': '후라이드',
#  '후라이드치킨후라이드': '후라이드',
#  '통날개후라이드': '후라이드',
#  '윙스타후라이드': '후라이드',
#  '순살후라이드': '후라이드',
#  '닭다리후라이드': '후라이드',
#  '매운후라이드': '후라이드',
#  '다리후라이드': '후라이드',
#  '바삭이후라이드': '후라이드',
#  '스낵후라이드': '후라이드',
#  '충만후라이드': '후라이드',
#  '허니치즈후라이드': '후라이드',
#  '다리핫후라이드': '후라이드',
#  '곱빼기후라이드': '후라이드',
#  '맛짱똥집후라이드': '후라이드',
#  '마늘후라이드': '후라이드',
#  '핫후라이드': '후라이드',
#  '땡초불꽃후라이드': '후라이드',
#  '날개핫후라이드': '후라이드',
#  '허니스윗후라이드': '후라이드',
#  '바싹후라이드': '후라이드',
#  '불닭후라이드': '후라이드',
#  '커리양념후라이드': '후라이드',
#  '치즈후라이드': '후라이드',
#  '바삭한핑크솔트후라이드': '후라이드',
#  '순살구운후라이드': '후라이드',
#  '불짬뽕치킨후라이드': '후라이드',
#  '똥집후라이드': '후라이드',
#  '가마로후라이드': '후라이드',
#  '오곡후라이드': '후라이드',
#  '간장매운간장치킨후라이드': '후라이드',
#  '뿌려봐유후라이드': '후라이드',
#  '해바라기후라이드': '후라이드',
#  '스윗츠갈릭치킨후라이드': '후라이드',
#  '치즈스노우퀸후라이드': '후라이드',
#  '치요남후라이드': '후라이드',
#  '매운맛후라이드': '후라이드',
#  '오미후라이드': '후라이드',
#  '닭안심후라이드': '후라이드',
#  '다리날개핫후라이드': '후라이드',
#  '윙봉후라이드': '후라이드',
#  '근위후라이드': '후라이드',
#  '한방숙성후라이드': '후라이드',
#  '닭발후라이드': '후라이드',
#  '옛날후라이드': '후라이드',
#  '돼지갈비후라이드': '후라이드',
#  '불고기후라이드': '후라이드',
#  '닭날개후라이드': '후라이드',
#  '닭똥집후라이드': '후라이드',
#  '교촌리얼후라이드': '후라이드',
#  '멕시듀오후라이드': '후라이드',
#  '한마리후라이드': '후라이드',
#  '오리지널후라이드': '후라이드',
#  '고추후라이드': '후라이드',
#  '뼈후라이드': '후라이드',
#  '깐풍후라이드': '후라이드',
#  '순살핫후라이드': '후라이드',
#  '통다리후라이드': '후라이드',
#  '다리날개후라이드': '후라이드',
#  '매니아후라이드': '후라이드',
#  '매콤후라이드': '후라이드',
#  '장수가마솥후라이드': '후라이드',
#  '치킨탕수육후라이드': '후라이드',
#  '교촌후라이드': '후라이드',
#  '멕시윙후라이드': '후라이드',
#  '땅땅똥집후라이드': '후라이드',
#  '달후라이드': '후라이드',
#  '치즈스틱포테이토': '포테이토',
#  '핫치킨포테이토': '포테이토',
#  '오리다리콩피와매쉬포테이토': '포테이토',
#  '콰트로포테이토': '포테이토',
#  '갈릭빠다포테이토': '포테이토',
#  '핫치즈볼포테이토': '포테이토',
#  '고르곤베이컨포테이토': '포테이토',
#  '해쉬브라운포테이토': '포테이토',
#  '단호박포테이토': '포테이토',
#  '크림치즈포테이토': '포테이토',
#  '소시지포테이토': '포테이토',
#  '소세지포테이토': '포테이토',
#  '반미터포테이토': '포테이토',
#  '순살바베큐치킨포테이토': '포테이토',
#  '모둠포테이토': '포테이토',
#  '스윗포테이토': '포테이토',
#  '길쭉이포테이토': '포테이토',
#  '트러플매쉬포테이토': '포테이토',
#  '프렌치포테이토': '포테이토',
#  '더블포테이토': '포테이토',
#  '타코포테이토': '포테이토',
#  '트러플포테이토': '포테이토',
#  '해쉬포테이토': '포테이토',
#  '딥치즈베이컨포테이토': '포테이토',
#  '핸드컷포테이토': '포테이토',
#  '봉구윙봉포테이토': '포테이토',
#  '유로피안포테이토': '포테이토',
#  '아이리쉬포테이토': '포테이토',
#  '위스콘신치즈포테이토': '포테이토',
#  '윙포테이토': '포테이토',
#  '애니멀포테이토': '포테이토',
#  '순살허니칠리치킨포테이토': '포테이토',
#  '매쉬포테이토': '포테이토',
#  '어니언포테이토': '포테이토',
#  '치즈베이컨포테이토': '포테이토',
#  '베이컨치즈칠리포테이토': '포테이토',
#  '소세지와포테이토': '포테이토',
#  '포테이토': '포테이토',
#  '어니언크림포테이토': '포테이토',
#  '햄치즈포테이토': '포테이토',
#  '치즈포테이토': '포테이토',
#  '콤보포테이토': '포테이토',
#  '왕새우튀김포테이토': '포테이토',
#  '교촌칠리포테이토': '포테이토',
#  '시즈닝포테이토': '포테이토',
#  '순삭포테이토': '포테이토',
#  '벨지안포테이토': '포테이토',
#  '모듬포테이토': '포테이토',
#  '크리미포테이토': '포테이토',
#  '크림치즈인스윗포테이토': '포테이토',
#  '갈릭버터포테이토': '포테이토',
#  '크런치포테이토': '포테이토',
#  '허니포테이토': '포테이토',
#  '미안한포테이토': '포테이토',
#  '폭탄치즈포테이토': '포테이토',
#  '허니모듬포테이토': '포테이토',
#  '베이컨포테이토': '포테이토',
#  '웨지포테이토': '포테이토',
#  '베이컨치즈포테이토': '포테이토',
#  '갈릭포테이토': '포테이토',
#  '샌드위치해쉬포테이토': '포테이토',
#  '매쉬드포테이토': '포테이토',
#  '요거프라노베블루베리': '블루베리',
#  '유기농블루베리': '블루베리',
#  '통블루베리': '블루베리',
#  '블루베리': '블루베리',
#  '파미그레네이트블루베리': '블루베리',
#  '아보카도블루베리': '블루베리',
#  '플레인딸기망고블루베리': '블루베리',
#  '생블루베리': '블루베리',
#  '베로나스파클링블루베리': '블루베리',
#  '플레인유자블루베리': '블루베리',
#  '크루져블루베리': '블루베리',
#  '파미그래네이트블루베리': '블루베리',
#  '베이글블루베리': '블루베리',
#  '토스트블루베리': '블루베리',
#  '요거트스무디블루베리': '블루베리',
#  '아로니아블루베리': '블루베리',
#  '닭한마리김치찌개': '김치찌개',
#  '등갈비김치찌개': '김치찌개',
#  '동삼겹김치찌개': '김치찌개',
#  '얼큰김치찌개': '김치찌개',
#  '한근김치찌개': '김치찌개',
#  '햄소시지김치찌개': '김치찌개',
#  '덩어리김치찌개': '김치찌개',
#  '울엄마김치찌개': '김치찌개',
#  '튀긴고기김치찌개': '김치찌개',
#  '꽁치떙초김치찌개': '김치찌개',
#  '통삼겹김치찌개': '김치찌개',
#  '마굿간김치찌개': '김치찌개',
#  '양푼김치찌개': '김치찌개',
#  '돈까스김치찌개': '김치찌개',
#  '양많이김치찌개': '김치찌개',
#  '숙성김치찌개': '김치찌개',
#  '소세지고기김치찌개': '김치찌개',
#  '고기듬뿍김치찌개': '김치찌개',
#  '마구리김치찌개': '김치찌개',
#  '안주김치찌개': '김치찌개',
#  '한우수지김치찌개': '김치찌개',
#  '국내산묵은지김치찌개': '김치찌개',
#  '옛날김치찌개': '김치찌개',
#  '돼지비엔나김치찌개': '김치찌개',
#  '돼지듬뿍김치찌개': '김치찌개',
#  '뚝배기김치찌개': '김치찌개',
#  '생고기김치찌개': '김치찌개',
#  '오징어김치찌개': '김치찌개',
#  '스팸김치찌개': '김치찌개',
#  '앞고기김치찌개': '김치찌개',
#  '갈비김치찌개': '김치찌개',
#  '고기듬북김치찌개': '김치찌개',
#  '묵은지김치찌개': '김치찌개',
#  '고등어김치찌개': '김치찌개',
#  '국산콩비지김치찌개': '김치찌개',
#  '두부김치찌개': '김치찌개',
#  '참치김치찌개': '김치찌개',
#  '삼거리김치찌개': '김치찌개',
#  '통목살김치찌개': '김치찌개',
#  '오겹김치찌개': '김치찌개',
#  '미주학당김치찌개': '김치찌개',
#  '두루치기김치찌개': '김치찌개',
#  '양은냄비김치찌개': '김치찌개',
#  '삼겹살김치찌개': '김치찌개',
#  '양푼이통돼지김치찌개': '김치찌개',
#  '등심김치찌개': '김치찌개',
#  '김치찌개': '김치찌개',
#  '얼큰돼지김치찌개': '김치찌개',
#  '양푼이김치찌개': '김치찌개',
#  '제주돼지김치찌개': '김치찌개',
#  '묵은지한돈김치찌개': '김치찌개',
#  '사태김치찌개': '김치찌개',
#  '고기김치찌개': '김치찌개',
#  '침치김치찌개': '김치찌개',
#  '통돼지김치찌개': '김치찌개',
#  '작품김치찌개': '김치찌개',
#  '어묵김치찌개': '김치찌개',
#  '마구로김치찌개': '김치찌개',
#  '덜미살김치찌개': '김치찌개',
#  '부대김치찌개': '김치찌개',
#  '돼지김치찌개': '김치찌개',
#  '한돈김치찌개': '김치찌개',
#  '불고기김치찌개': '김치찌개',
#  '파김치찌개': '김치찌개',
#  '종합김치찌개': '김치찌개',
#  '순두부김치찌개': '김치찌개',
#  '매콤돈김치찌개': '김치찌개',
#  '통문어김치찌개': '김치찌개',
#  '삼겹살백김치찌개': '김치찌개',
#  '만두김치찌개': '김치찌개',
#  '쌈싸먹는김치찌개': '김치찌개',
#  '흑돼지김치찌개': '김치찌개',
#  '생고기뚝배기김치찌개': '김치찌개',
#  '후식김치찌개': '김치찌개',
#  '목살꽁치김치찌개': '김치찌개',
#  '특미김치찌개': '김치찌개',
#  '돼지고기김치찌개': '김치찌개',
#  '할머니김치찌개': '김치찌개',
#  '옛날식김치찌개': '김치찌개',
#  '양푼얼큰김치찌개': '김치찌개',
#  '돈가스김치찌개': '김치찌개',
#  '목살김치찌개': '김치찌개',
#  '제주생고기김치찌개': '김치찌개',
#  '양푼돼지김치찌개': '김치찌개',
#  '꽁치김치찌개': '김치찌개',
#  '창정이형김치찌개': '김치찌개',
#  '한돈통돼지김치찌개': '김치찌개',
#  '오뎅김치찌개': '김치찌개',
#  '숙성짖김치찌개': '김치찌개',
#  '삼겹김치찌개': '김치찌개',
#  '부안김치찌개': '김치찌개',
#  '라면김치찌개': '김치찌개',
#  '도야지김치찌개': '김치찌개',
#  '곤드레장칼국수불고기': '불고기',
#  '치아바타불고기': '불고기',
#  '직화쭈삼불고기': '불고기',
#  '오낙불고기': '불고기',
#  '활참복불고기': '불고기',
#  '옹심이치즈불고기': '불고기',
#  '달콤불고기': '불고기',
#  '오징어불고기': '불고기',
#  '더블바베큐불고기': '불고기',
#  '매콤불고기': '불고기',
#  '화로불고기': '불고기',
#  '알밥숯불고기': '불고기',
#  '바싹불고기': '불고기',
#  '복숭아불고기': '불고기',
#  '궁중불고기': '불고기',
#  '한촌불고기': '불고기',
#  '버섯불고기': '불고기',
#  '옛날실불고기': '불고기',
#  '치즈불고기': '불고기',
#  '염소불고기': '불고기',
#  '버섯생불고기': '불고기',
#  '한우소불고기': '불고기',
#  '연탄고추장불고기': '불고기',
#  '언양불고기': '불고기',
#  '탄탄불고기': '불고기',
#  '뚝불고기': '불고기',
#  '할라불고기': '불고기',
#  '철판산더미불고기': '불고기',
#  '오돼지불고기': '불고기',
#  '까망베르치즈불고기': '불고기',
#  '북성로석쇠불고기': '불고기',
#  '신선불고기': '불고기',
#  '서울불고기': '불고기',
#  '고추장연탄불고기': '불고기',
#  '매실돈육양념불고기': '불고기',
#  '생오리불고기': '불고기',
#  '한우일품진미불고기': '불고기',
#  '오사카아먁불고기': '불고기',
#  '반미터불고기': '불고기',
#  '맵소불고기': '불고기',
#  '한우광양불고기': '불고기',
#  '한우불고기': '불고기',
#  '한우숯불고기': '불고기',
#  '엄청난대패불고기': '불고기',
#  '반찬소불고기': '불고기',
#  '얼큰이장칼국수불고기': '불고기',
#  '국물불고기': '불고기',
#  '열탄불고기': '불고기',
#  '아구불고기': '불고기',
#  '생선불고기': '불고기',
#  '뚝배기소불고기': '불고기',
#  '떡만두국숯불고기': '불고기',
#  '양념불고기': '불고기',
#  '석쇠파불고기': '불고기',
#  '촌돼지불고기': '불고기',
#  '직화돼지불고기': '불고기',
#  '치즈크러스트베이컨불고기': '불고기',
#  '따닥불고기': '불고기',
#  '고추장소불고기': '불고기',
#  '활복불고기': '불고기',
#  '직화불고기': '불고기',
#  '돼지양념불고기': '불고기',
#  '화끈불고기': '불고기',
#  '돼지숯불고기': '불고기',
#  '닭불고기': '불고기',
#  '담소불고기': '불고기',
#  '복어불고기': '불고기',
#  '해정식불고기': '불고기',
#  '한우양념불고기': '불고기',
#  '야채생오리불고기': '불고기',
#  '양념석쇠불고기': '불고기',
#  '소숯불고기': '불고기',
#  '쭈삼불고기': '불고기',
#  '핫불고기': '불고기',
#  '비빔밀면돼지불고기': '불고기',
#  '어니언불고기': '불고기',
#  '불고기': '불고기',
#  '에그불고기': '불고기',
#  '뿜뿜불고기': '불고기',
#  '한우등심불고기': '불고기',
#  '간장연탄불고기': '불고기',
#  '산더미불고기': '불고기',
#  '자연소스로맛을낸불고기': '불고기',
#  '자연산불고기': '불고기',
#  '한우생불고기': '불고기',
#  '광양불고기': '불고기',
#  '광화문불고기': '불고기',
#  '리얼불고기': '불고기',
#  '물냉면숯불고기': '불고기',
#  '유황오리불고기': '불고기',
#  '김치찌개숯불고기': '불고기',
#  '비빔냉면숯불고기': '불고기',
#  '철판복불고기': '불고기',
#  '매콤콩불고기': '불고기',
#  '불고기파불고기': '불고기',
#  '생아구불고기': '불고기',
#  '소뚝불고기': '불고기',
#  '맛있는옛날불고기': '불고기',
#  '옛맛서울불고기': '불고기',
#  '철판소불고기': '불고기',
#  '한우언양불고기': '불고기',
#  '석쇠불고기': '불고기',
#  '간장불고기': '불고기',
#  ...}

# %%
df_menu = pd.DataFrame(columns=['title', 'category'], data=menu_cluster.items())
len(df_menu['category'].unique())
# Out:
# 139

# %%
df_menu.sample(50)
# Out:
#              title category
# 13623   치즈닭갈비철판닭갈비       갈비
# 17809       마왕갈릭족발       족발
# 15292       복숭아에이드       이드
# 14303   카라멜치즈그린티밀크       밀크
# 23095           윙떡        떡
# 16332        카페다커피       커피
# 9714        매운순대볶음       볶음
# 8066         메밀전추가       추가
# 14972        은쏨에이드       이드
# 21121         크림맥주       맥주
# 9246         프렌치라떼       라떼
# 12264       그릴가지구이       구이
# 6986     블루베리베이글세트       세트
# 9802         순살닭볶음       볶음
# 23216     하루시카준마이팩        팩
# 4196        개성손칼국수      칼국수
# 14404         제일우동       우동
# 20542  국물이끝내주는잔치국수       국수
# 4229         어탕칼국수      칼국수
# 4415      매운해산물쌀국수      쌀국수
# 20498      문래동잔치국수       국수
# 2049         카레돈까스      돈까스
# 25651      해물매콤짬뽕탕        탕
# 14755         특불짬뽕       짬뽕
# 25709        삼선롱샤탕        탕
# 16973        낙지한마리       마리
# 22810      크랜베리자몽티        티
# 24827      치킨멀라이케밥        밥
# 5575          시저치킨       치킨
# 13990      낙지소곱창전골       전골
# 13151         메밀정식       정식
# 8979     아이스블루베리라떼       라떼
# 11610     허니포테이토피자       피자
# 3754       한방숯불삼겹살      삼겹살
# 8830       벨기에초코라떼       라떼
# 15532        탕수육김밥       김밥
# 22530    루이보스허니밀크티        티
# 25192         알내장탕        탕
# 19592     데리야끼구이꼬치       꼬치
# 2843   철판소고기양송이볶음밥      볶음밥
# 57      어반브런치아메리카노    아메리카노
# 4288         밀크바닐라      바닐라
# 20908        오늘의메뉴       메뉴
# 8817       티파니블루라떼       라떼
# 3908        콰트로고구마      고구마
# 25237       알고니동태탕        탕
# 15756      매운맛오튀김밥       김밥
# 16985    고추마늘치킨한마리       마리
# 9546        고기단콩볶음       볶음
# 4260     옛날고추장손칼국수      칼국수

# %%
# 미분류
non_category = []
for i in menu:
  if i not in menu_cluster:
    non_category.append(i)

len(menu), len(non_category)
# Out:
# (51437, 24408)

# %%
non_category
# Out:
# ['딸기탄산수',
#  '콜드브루단품',
#  '카페모카',
#  '베이컨꼬지',
#  '오색양장피',
#  '가로막살주물럭',
#  '코코넛연유라테',
#  '멕시콜라',
#  '텐시노유와쿠',
#  '참치크루아상',
#  '오도상',
#  '스테이크리조토',
#  '치즈떡프라이',
#  '바리스타추천재배지',
#  '가마로윙',
#  '에그누들',
#  '모듬계란말이',
#  '횟간',
#  '찐대게',
#  '월넛크럼블',
#  '부리또소다칩스',
#  '민어',
#  '진저에일',
#  '치즈스틱버팔로윙',
#  '생크림과일파이',
#  '소세지플래터',
#  '시나몬크로',
#  '기문',
#  '몬스타따블핫도그',
#  '와사비관자치즈뽂음',
#  '앱솔루트단품',
#  '고기만두크러스트',
#  '양대창',
#  '차돌된장찌개',
#  '미나미토쿠베츠준마이',
#  '디저트',
#  '달커밀크티병',
#  '보데가스엘니도클리오',
#  '쯔께모노',
#  '치킨브라더스',
#  '콩불',
#  '한치랑땅콩',
#  '키조개버터구이관자',
#  '사과쥬스탄산',
#  '피오체사레돌체토달바',
#  '후라이드봉만',
#  '에스프레소사케라또',
#  '치킨파니니',
#  '달인쌍화차',
#  '이베리코베요타소세지',
#  '딸기스노우',
#  '수자육편',
#  '생딸기타르트',
#  '치즈닭강정',
#  '국내산생항정살',
#  '불족원쌈',
#  '오리다리콩피',
#  '해물짬뽕누들',
#  '콘핫도그',
#  '애간장녹는닭레드',
#  '멸치액젓',
#  '뽕잎차와다과',
#  '연태고량주대',
#  '널만난건행운이야',
#  '슈프림시카고딥디쉬피자콜라',
#  '쉬림프고르곤졸라',
#  '어묵완자',
#  '월남쌈한우샤브',
#  '피자브레드',
#  '크림치즈고로케',
#  '와다',
#  '양푼짜글이',
#  '통꼬막데침',
#  '왕닭',
#  '참치타다키',
#  '원두빵커피맛',
#  '쭈꾸미차돌박이',
#  '소고기육개장만구매시',
#  '찹쌀동동주',
#  '베지테리안',
#  '차옌',
#  '황고망고쥬스',
#  '샌드위치셋트',
#  '만족원쌈',
#  '양배추즙',
#  '닷사이',
#  '돼지불고기밥상',
#  '앵무세그라세',
#  '메이플',
#  '타라파카그란레세르바까르메네르',
#  '핑크포멜로블렌디드',
#  '양파사라시',
#  '호르몬뇨끼',
#  '유자민트스쿼시',
#  '잡버섯찌개',
#  '수자생선',
#  '탕수육고추짜장',
#  '칠성간장찜닭',
#  '하이산라이스',
#  '파놀멜롯리지브',
#  '마늘순살',
#  '비냐마이포카베네멜롯',
#  '프리미어',
#  '부추수저교',
#  '엽도그',
#  '가츠돈',
#  '우노말벡',
#  '불고기월넛파니니',
#  '산펠레그리노스파클링',
#  '미인보이차',
#  '매운치킨마요동',
#  '새우크래미롤',
#  '수제청청귤',
#  '브루잉',
#  '멘마',
#  '수박쥬스',
#  '알싸후추',
#  '김치가츠나베',
#  '치즈킹소떡소떡롤',
#  '둥지백반',
#  '월남쌈샤브',
#  '청년너겟',
#  '참치뱃살모듬',
#  '부용게살',
#  '복분자스파클링',
#  '초청채',
#  '게살상어지느러미스프',
#  '파',
#  '완전수박',
#  '토리파이탄',
#  '민트아이스치노',
#  '캔흑당우유',
#  '대선',
#  '한스페일에일',
#  '메론맛',
#  '샤또플라네르샹따이',
#  '이안원두',
#  '김치찌개단품',
#  '보쌈대족발대막국수대',
#  '마라관자',
#  '꿍빠오치킨게살스프',
#  '옛날잔치편육',
#  '초코미니크로와상',
#  '슈크림아인슈페너',
#  '맥캘란셰리캐스크',
#  '모짜렐라토마토새우딸리아뗄레',
#  '사뮤엘아담스보스턴라거',
#  '날치알쌈',
#  '수',
#  '꽃비차',
#  '약초백숙',
#  '레몬청',
#  '잉글리쉬커피셋트',
#  '통영석화',
#  '라임모히토',
#  '오트밀피칸쿠키',
#  '철판찐토빠노',
#  '눈다랑어참다랑어',
#  '모찌고로케',
#  '베이컨할라피뇨',
#  '줄리엔프라이스',
#  '치즈비엔나소세지',
#  '김치지개',
#  '양등갈비살',
#  '카페비엔나',
#  '닭껍질카라아게',
#  '인세트두루치기밥인',
#  '레드블보드카',
#  '흑백사진',
#  '모듬생선조림',
#  '햄치즈파니니',
#  '마오두',
#  '굽네허니멜로통다리',
#  '카페가츠동',
#  '소막창불찜',
#  '생우럭매운탕대',
#  '플랏화이트',
#  '사케장',
#  '머릿고기한접시',
#  '순살고추마요',
#  '전국지한판전',
#  '염통고치',
#  '마늘돈카츠',
#  '인어공주가리비찜',
#  '망바',
#  '쿠키박스',
#  '반반세트굽네통날개굽네순살',
#  '크림마레',
#  '스쿱',
#  '믹스쳐',
#  '퍼스트러브',
#  '꼬마김밥개',
#  '양송이스프',
#  '탱커레이진토닉',
#  '브룩라딕블랙아트',
#  '카다이파니르',
#  '핫바베큐',
#  '드립백호',
#  '폭탄피자콰트로포르마지오',
#  '쟁반고기쌈',
#  '패밀리슈퍼콤비네이션석쇠',
#  '팔보채짜장',
#  '매운유부',
#  '뚝배기두루치기',
#  '다리조각',
#  '부리또탄산음료',
#  '스트로베리툴시',
#  '스트롱빈',
#  '애플사이더',
#  '통다리바베큐',
#  '코다리해물찜',
#  '대나무죽통주',
#  '돼지김치째개',
#  '밀푀유나베',
#  '치즈반바니아',
#  '꼼장어',
#  '콤비네이션중',
#  '한우암소',
#  '티토스샷',
#  '옥수수전',
#  '소불고기포케',
#  '가족의족보',
#  '보르도샤또망비엘화이트',
#  '플레인요거트칠라타',
#  '산서량피',
#  '샤또프라네르라로마니',
#  '연밥포장',
#  '루비쿨러',
#  '칠리치킨강정',
#  '팬수퍼슈프림',
#  '날치롤',
#  '제주목살',
#  '명태식해',
#  '매콤찹스',
#  '써니깜빠뉴',
#  '모카영양',
#  '숯불구이무한리필',
#  '유니콘프라페',
#  '세꼬시',
#  '요리변경시',
#  '램앞다리살',
#  '옥수수수염차',
#  '흑미칠리페퍼베이글',
#  '인동',
#  '아이스크림과일와플',
#  '환타파인',
#  '밀차슈페너',
#  '제주꽃목살',
#  '간바래오또상',
#  '사시미한상처럼',
#  '에스프레소아이스그램',
#  '더치스노우',
#  '갈릭누들프론',
#  '카오팟가이',
#  '깨오이',
#  '정글새',
#  '데친오징어말이',
#  '콜드플레터',
#  '진천덕산',
#  '소스패키지',
#  '곱빼기변경시',
#  '블루베리요거트익스트림',
#  '투썩점퍼피노누아',
#  '순수우유케익',
#  '불고기치즈굿브레드',
#  '로얄블렌드',
#  '향라대하',
#  '왕돈샌선까스떡볶돈매운돈고구마돈오뎅음료',
#  '생크림크라상입',
#  '바카디콕',
#  '아이스헤이즐넛',
#  '쫀도그',
#  '와규타나끼',
#  '새우튀김소바',
#  '산멜레그리노',
#  '하프앤하프트리플스탠다드세트페밀리세트초리조선택시',
#  '낙지탕탕이',
#  '모카칩프라페',
#  '경장육스',
#  '슈니첼런치',
#  '새우토마토리조또',
#  '베이컨피자치아바타',
#  '와규샤브샤브평일런치',
#  '샐러디',
#  '이과두',
#  '레몬석류',
#  '돌게장포장',
#  '치즈꽈배기',
#  '긴자벤또',
#  '시래기코다리찜',
#  '누가크래커개별포장시',
#  '블랑블랑치즈베리호',
#  '피칸테만조에루꼴라',
#  '오리샤브',
#  '수제대추차',
#  '쌀통닭반반',
#  '아이스티복숭아',
#  '갈빗살모듬',
#  '초코볼케이노',
#  '크리스피갈릭바게트',
#  '산미구엘페일필젠',
#  '냉동한우국거리',
#  '스페셜크로와상',
#  '바지락순두부찌개',
#  '빅플래터',
#  '윙봉레드',
#  '명태구이찜',
#  '화이타',
#  '한우꽃갈비살',
#  '남도모듬',
#  '활어참복',
#  '과일차자몽차',
#  '바닐라파르페',
#  '감자포크소세지',
#  '추가미나리',
#  '민트초코프라푸노',
#  '말차슈패너마시기',
#  '꼬리찜대',
#  '목우촌골드윙',
#  '빵속에빠진스프브런치',
#  '제로콜라',
#  '곤드레나물전병',
#  '과일꽃차',
#  '밀땅바이젠',
#  '오미자',
#  '특안심',
#  '허니멜론프라페',
#  '치킨샤브레',
#  '고기고로케',
#  '칠리바베큐',
#  '간장윙봉',
#  '블랙카페모카',
#  '비트레몬청',
#  '부타라이스커리',
#  '화끈제대로두루치기',
#  '삼선해물쟁반짜장',
#  '블랙밀크티크러쉬커피밀크티크러쉬',
#  '요거플러터',
#  '알찬만두국백반',
#  '과일플레이트',
#  '야채참치죽',
#  '통갈비찜',
#  '애플시나몬와플',
#  '소고기국밥돌솥',
#  '사천식라조기',
#  '사케센',
#  '피노블랑젤렌버그',
#  '커피칵테일',
#  '전복찜미',
#  '버드와이져',
#  '고구마티라미스를만나다',
#  '유자티마시기',
#  '카페젤라또',
#  '더블바베큐크러스트',
#  '레자르젤리에르',
#  '매운골뚜기',
#  '가츠샌드',
#  '준마이쿠시',
#  '불짬뽕치킨패키지',
#  '위스키보드카진',
#  '라미소노마코스트샤르도네',
#  '동충하초한방오리백숙',
#  '뿌팟뽕커리',
#  '제주생오겹',
#  '다인하드그린라벨',
#  '생선카츠',
#  '패트론실버',
#  '양념반갈릭반',
#  '라임키위',
#  '페리에주에벨레포크',
#  '복숭아라씨',
#  '굽네반반순살',
#  '아몬드',
#  '시앤수지',
#  '바닷내음멍게',
#  '쉐이킹시즈닝나초',
#  '로즈마리허브차',
#  '마마스시그니쳐',
#  '피치쿼츠',
#  '해산물스파게티새우관자홍합한치',
#  '아메푸치노',
#  '사시미모리아와세',
#  '통삼겹스테끼',
#  '홍차',
#  '닭백숙',
#  '다크초콜릿데카당스',
#  '고추장돼지뚝불',
#  '부리또',
#  '감자체다스프',
#  '라즈베리초코칩머핀',
#  '머턴고르마',
#  '카레토핑',
#  '생선매운탕대',
#  '파인트',
#  '과메기청어과메기',
#  '체리뱅쇼',
#  '농가삼보요리',
#  '대구탕지리',
#  '마라곱탄멘',
#  '햄치즈땡초',
#  '보드카믹스',
#  '미켈러대동강',
#  '블렌딩티맑은유자',
#  '치즈싱글탄산음료잔',
#  '사천해물천왕',
#  '최상급보이차',
#  '갈릭치즈프렌치프라이',
#  '바지락칼수제비',
#  '바이젠',
#  '누룽지한방통닭',
#  '상해',
#  '자연산활어해초세꼬시',
#  '스팸계란말이',
#  '카라멜마끼아또카페모카',
#  '순두부찌게',
#  '바닐라버본',
#  '행복수제비',
#  '와인류',
#  '월남쌈명품한우샤브샤브',
#  '특전복죽',
#  '문라이즈페일에일',
#  '발로나민트초코프라페',
#  '뉴욕오리진트리플치즈버스트엣지',
#  '버터갈릭후라이',
#  '소이스틱',
#  '이스트포',
#  '츠케모노종',
#  '새우전',
#  '방어',
#  '갑이두',
#  '밤패스트리',
#  '순살주문시',
#  '철관음',
#  '왕대박냉모밀',
#  '녹차마카롱',
#  '해물미고렝',
#  '월남쌈커플셋트',
#  '등심불고기구이상차림',
#  '햄튼',
#  '소고기껍질',
#  '처세술',
#  '오목집계란말이',
#  '유자프라푸치노',
#  '카페마끼아또',
#  '어전',
#  '서핑애플',
#  '낙지미',
#  '딸기누텔라젤라또와플',
#  '그린사라다',
#  '골뱅이찜',
#  '숙성연어사시미혼술플래터',
#  '돼지꼬들살',
#  '패티플래터',
#  '생연어초밥개',
#  '오직순대만',
#  '퀸앤블랜드',
#  '하디',
#  '피데기',
#  '꼬막파전',
#  '비프스트로가노프',
#  '리퀴드코카인',
#  '갈매기',
#  '이베리코목살',
#  '콩나물뼈찜',
#  '한라산',
#  '히비스커스뱅쇼',
#  '매콤양념막창',
#  '뼈다귀해장국특',
#  '로제찜닭',
#  '더블쥬니어',
#  '안창',
#  '애플유자차',
#  '불고기유부',
#  '양념단품',
#  '훈제오리수육세트정원된장포함',
#  '도넛스틱',
#  '소고기필라프인',
#  '레몬스쿼시',
#  '로스트버팔로잉',
#  '골뱅이포',
#  '윙봉허니츄',
#  '얼음배즙',
#  '카제노모리아키츠호',
#  '카라멜블렌디드',
#  '시로미고노와다',
#  '소이크런치콤보',
#  '오렌지사와',
#  '강원도감자전',
#  '생선까스도련님',
#  '버터꿀봉',
#  '생과일토마토쥬스',
#  '매생이전',
#  '초코크로아상',
#  '쿠바모히또',
#  '명태통살생선까스',
#  '프로방스',
#  '불제육',
#  '하이자빤',
#  '투게더',
#  '부쉬밀',
#  '청양간장파닭',
#  '치왕',
#  '우나기타마고야끼',
#  '시메이블루그랑리져브',
#  '특냉채',
#  '양푼돼지갈비찜',
#  '더블비시그니처',
#  '아메리카노리필',
#  '우우',
#  '민트초코오레오프라페',
#  '팥송송',
#  '감자홀딱',
#  '새우갈릭로스트',
#  '칠리베이컨웜볼',
#  '쟁반냉모밀',
#  '구운치즈후랑크',
#  '초코쿠키자바칩프라페',
#  '경장육사',
#  '모듬중',
#  '매운돈코츠라멘',
#  '생연어말이',
#  '생삼겹살특수부위',
#  '된장신라멘',
#  '활어',
#  '등갈비바베큐',
#  '수육고기추가시',
#  '윈터뱅블랑',
#  '동태지리',
#  '한돈모듬한판',
#  '매운불',
#  '돼지염통줄기',
#  '이네아시라',
#  '쇼콜라디아망',
#  '강화전',
#  '고르곤졸라뇨끼',
#  '생조개',
#  '해산물리조또',
#  '돈가스조각',
#  '수제마카롱',
#  '블루베리히비스커스',
#  '둘둘둘',
#  '가지비프토마토리조또',
#  '파채순살',
#  '구워먹는마쉬멜로',
#  '더블초코칩브라우니',
#  '올갱이야채비빔밤',
#  '메이플카푸치노',
#  '썸주',
#  '낙지접시',
#  '계절모듬사시미',
#  '송이기편',
#  '송사부아인슈페너',
#  '허니크림치즈크래커',
#  '클래식마타니',
#  '통나무마을동물친구들',
#  '삿보로',
#  '회해산물',
#  '홍소굴비',
#  '생딸기우유',
#  '버터브레첼',
#  '유기농코코아',
#  '간장찜닭',
#  '가오리다데기찜',
#  '크림치즈가라아게',
#  '하비스트보울',
#  '새싹오래오레',
#  '전복광어사시미',
#  '캐모마일블렌딩',
#  '마요복분자',
#  '관자전복요리',
#  '코다리시래기조림',
#  '블루베리치즈브레드',
#  '카페라테',
#  '어탕수제비',
#  '대패갈비살',
#  '고급회특',
#  '북어계란말이',
#  '리얼대추차',
#  '그레이프프루트',
#  '만조풍기로조또',
#  '고르곤졸라피자반콤비네이션피자반',
#  '마이갈비포장',
#  '블루베리요거트아이스블렌디드',
#  '참치김치짜글이',
#  '돌짜장',
#  '하노이식튀긴스프링롤',
#  '스패셜황도',
#  '소갈비찜대',
#  '돼지고기듬뿍김치찜',
#  '미스터트리오',
#  '좀비브레인',
#  '신선다리',
#  '카야',
#  '풀토핑',
#  '바닐라홀파운드',
#  '일품소갈비찜',
#  '스팸부대찌개',
#  '호두피넛초코칩쿠키',
#  '딸기아인슈페너',
#  '롱소세지핫도그',
#  '청주도꾸리',
#  '윙봉맛깔난어니언',
#  '불족',
#  '도로가메',
#  '덕산막걸리',
#  '마라룽샤재료자유선택',
#  '매콤알닭',
#  '낙지등갈비찜',
#  '숯불닭양념바비큐',
#  '말차누텔라다쿠아즈',
#  '사라다소바',
#  '망고젤리',
#  '오키나와산소금우유',
#  '닭다리살가라아게',
#  '풍천장어한판',
#  '요세나베',
#  '영광먹소',
#  '자연송이죽',
#  '팔팔오디',
#  '매생이게살샥스핀스프',
#  '감베리페쉐',
#  '산타캐롤리나브이에스씨',
#  '헤니즐넛시럽',
#  '나쵸살사',
#  '초콜릿아포가토',
#  '암돼지목살',
#  '플레인라이타',
#  '부추된장찌개',
#  '우럭스끼다시종',
#  '갈비단콩',
#  '산오징어먹퉁',
#  '켈슈',
#  '노말한소프트초코렛',
#  '안심알리오올리오',
#  '제주말차프라페',
#  '커피젤리바닐라크러쉬',
#  '바비큐렌치',
#  '까치복찜',
#  '유자차와다과',
#  '돈항정살묵은지',
#  '꽃게커리새우커리',
#  '파절이',
#  '카라멜에스프레소',
#  '동글동글순우유롤',
#  '럭스브륏',
#  '차돌두루치기',
#  '양념한판맛보기',
#  '콘치즈브레드',
#  '은복수육',
#  '체다치즈볼',
#  '투뿔한우주물럭',
#  '샐러드닭가슴살',
#  '노설원',
#  '프라임갈비살',
#  '우마미그레인보울',
#  '프렌치바닐라라테',
#  '특제대추',
#  '아와비엔쵸비챠항',
#  '토피넛카페라떼휘핑',
#  '아메리카노동일',
#  '아인슈패너라떼마시기',
#  '치킨티카마살라',
#  '간창치킨순살',
#  '따로섞어',
#  '체리익스트림',
#  '팟씨유',
#  '피치플럼드롭치노',
#  '오이보리된장',
#  '옥수수스프',
#  '달위니년',
#  '콜드브루아인슈페너',
#  '불치즈콘닭',
#  '츄러스치즈볼',
#  '크러스트와엣지링및치즈플러스는메뉴선택시원씩할인됩니다',
#  '청국장찌개백반',
#  '일글리시브랙퍼스트',
#  '린데만스뻬슈레제',
#  '대술',
#  '꼬끄과자',
#  '크림해물리조또',
#  '페파로니버터페스츄리',
#  '구어바',
#  '백고동',
#  '영광법성포보리굴비',
#  '매운양념주물럭',
#  '쇼콜라후랑보아즈',
#  '깐풍',
#  '테군',
#  '헤이패티프라이즈',
#  '차돌구이월남쌈샤브샤브',
#  '해물떡복이',
#  '블루마가리타',
#  '수제생선가스',
#  '양념돼지껍질',
#  '달터드까',
#  '고추쟁반짜장',
#  '흰살생선사시미',
#  '요거통통메론설빙',
#  '매콤치즈카츠',
#  '브리야니',
#  '도미',
#  '껍데기항정살',
#  '얼큰왕갈비찜',
#  '생딸기스콘',
#  '엠샤푸티에마리우스블랑',
#  '오리부추',
#  '회특선',
#  '하동말차',
#  '치즈바',
#  '골든블루다이아몬드',
#  '죠리퐁주택치노',
#  '고돼지정식곱빼기',
#  '송백특선생선찜',
#  '뽀므리브뤼로얄',
#  '진한녹차브라우니',
#  '낙지젓갈',
#  '뜨레스루스뜨로스그란리제르바브룻나뚜레',
#  '깔라만시에이드소',
#  '낫또군함말이',
#  '갈치',
#  '바닐라아이스멜론소다',
#  '통영가리비',
#  '베이클',
#  '울산쫀디기생맥잔',
#  '얼큰짜장',
#  '치즈스노윙반양념반',
#  '밥상',
#  '쉬림프까르보나라',
#  '소스선택',
#  '가마로봉',
#  '프리미엄완자부대찌게',
#  '민트칩프라프치노',
#  '팬케이크밀',
#  '다카시미즈준마이',
#  '상큼황도',
#  '생맥주무제한',
#  '미도리샤워',
#  '카푸치노오리지널블라스트',
#  '새우쩡쨔오',
#  '앙버터크래커',
#  '매운홍합찜',
#  '쌈밥불고기백반',
#  '갈비찜중',
#  '새우벌집퐁듀',
#  '월송국수큰죽',
#  '대도명품한우육개장',
#  '고구마엣지',
#  '시즌과일타르트',
#  '스텔라스모크덕',
#  '오레오초코디몰리쉬',
#  '아일랜드이스터샤도네이',
#  '로제파스타빠네갈릭버터브레드',
#  '수박바',
#  '서라멘',
#  '하이트캔',
#  '홈메이드음료',
#  '참좋은생생함박',
#  '아가리코하이볼',
#  '삿뽀로',
#  '뚝배기돼지갈비찜',
#  '녹차오루비치노',
#  '낙대',
#  '오몽쥬스',
#  '페스카토레리조또',
#  '쟈크샤를레셀레시옹루즈',
#  '해봉이',
#  '함지박뼈다귀',
#  '세트메뉴크로와상크림리조또',
#  '모듬회스끼다시종',
#  '보해복분자',
#  '국내산돼지생목살',
#  '유기농바닐라민트차이',
#  '자연산송이전복버터야끼',
#  '미니가라아게',
#  '화이트바게트',
#  '슈퍼디럭스곡물도우',
#  '미니돈수육',
#  '호두캬라멜다쿠아즈',
#  '자메이카여행',
#  '참치담은김치찌개인',
#  '연태랑',
#  '수주육편',
#  '아규수육',
#  '달달호박',
#  '돼지양념막창',
#  '스페셜류',
#  '참돔어종모듬',
#  '딸기쏙쏙',
#  '치즈고로케',
#  '소고기육개장',
#  '통마늘김치두루치기',
#  '활아구찜',
#  '쥐포황도',
#  '소고기요리',
#  '장육면옥',
#  '꾸에띠오똠양',
#  '러스굴라',
#  '치킨커리',
#  '멜럿',
#  '콜라사이즈업',
#  '치즈감자전',
#  '이빠이',
#  '월계수전복찜',
#  '트러플치즈볼',
#  '아인슈페너헤이즐넛모카',
#  '매운왕계란말이',
#  '왕돈큰쫄떡볶이새우우동만두음료',
#  '음료뚱캔',
#  '오디',
#  '메가불닭치킨마요',
#  '마얀콘튀생맥잔',
#  '초콜릿크림칩',
#  '가끼아게텐동',
#  '육회빕빔밥용밥과고추장과채소',
#  '갈비본색',
#  '빅까베르네쇼비뇽',
#  '구수한누룽지',
#  '화삼오가피술',
#  '돈모듬',
#  '아이스포도',
#  '떡볶이모듬',
#  '버드나무즈므블랑',
#  '새우튀김고로케',
#  '보름달메밀크레이프',
#  '만두탕해물파전',
#  '누룽지치즈불닭',
#  '골드스윗크러스트',
#  '닭간장조림',
#  '통새우스프',
#  '갈릭쉬림프알리오올리오',
#  '감베리오일',
#  '반반이',
#  '땡초고로케',
#  '황도화채',
#  '코노수르비씨클레타게브르츠트라미너',
#  '규야끼',
#  '주도로',
#  '비나마이포카비넷멜롯',
#  '보통',
#  '만조리코타',
#  '우룡해삼',
#  '상큼하고달구나패스트리',
#  '토스트앤깜빠뉴',
#  '전국일주막걸리',
#  '반건조노가리',
#  '오레오아토치노',
#  '스노윙치즈반양념반',
#  '잡고기조림',
#  '또봉이고추통닭',
#  '모든곱배기양많이',
#  '명란크림야끼소바',
#  '쉐이커라또',
#  '시카고딥',
#  '그린맨션',
#  '친환경야채참치죽',
#  '매생이복죽',
#  '김치치즈카츠나베',
#  '건강차',
#  '마라바지락',
#  '전복아구찜',
#  '대새우깐풍',
#  '난',
#  '착한밥상',
#  '대관령황태강정',
#  '이베리코이겹살',
#  '인달콤',
#  '음료수캔',
#  '한방장수닭백숙',
#  '콩까스',
#  '롤케잌',
#  '씨푸드아일랜드',
#  '뵈브블리코',
#  '켄터키젠틀맨',
#  '연태고량주',
#  '생크림케익호',
#  '싱글킹',
#  '즉석쫄볶이',
#  '아이스초키초키',
#  '추가뭉티기',
#  '송이버섯소주아임파인',
#  '전통갈비찜',
#  '오삼불고기한판',
#  '월계관준마이',
#  '순살양파닭',
#  '붕장어전복샤브샤브',
#  '토핑킹',
#  '후라이드반매콤아삭반',
#  '후라이드반데리야끼반',
#  '하우스미소백숙',
#  '북유럽감성시간숙성연어그라브락스',
#  '토마토안심리조또',
#  '해물모듬직화',
#  '그루토블랜딩',
#  '화이트모카',
#  '아까뎀푸라',
#  '감귤크로플샌드',
#  '꼬냑잔',
#  '자스민차',
#  '간장목살',
#  '플레인핫도그',
#  '숙성사시미인분수비드목살스테이크새우튀김가지모찌추천요리중택일',
#  '일반닭',
#  '마라쇼롱사',
#  '초코쿠키',
#  '살고기모듬수육',
#  '말차라테',
#  '불족발대',
#  '솜씨맵쌈',
#  '찹쌀치즈핫도그',
#  '그릴소세지튀김안주',
#  '너그대로의모습',
#  '코코넛라뗴',
#  '브로스바이젠',
#  '족발고급형',
#  '도자기',
#  '핫스파이스',
#  '꿀배차',
#  '유어홈커피프라페',
#  '아스파라거스안심',
#  '레드시트러스',
#  '제주그린밀크티펄',
#  '덴뿌라모리아와세',
#  '코코넛커피쉐이크',
#  '얼큰불고기김치죽',
#  '해산물팟타이',
#  '심백야마다니시키준마이다이긴죠',
#  '카페라떼사이즈',
#  '꽃삼',
#  '수제함박스테이크단품',
#  '순수바닐라롤',
#  '어니언치킨순살',
#  '어린이메밀',
#  '블루베리우유',
#  '매콤두부조림',
#  '규나베',
#  '바질페스토',
#  '데리야끼바베큐',
#  '마약옥수수감튀',
#  '바지락파전',
#  '삼색말차라떼마시기',
#  '히레안심까스모밀',
#  '흑당버블우유',
#  '가미가제',
#  '달고나밀크쉐이크',
#  '페데리코파테르니나레세르바',
#  '스페셜계란말이',
#  '딝강정',
#  '엘하워드리제르바까베르네쇼비뇽',
#  '오레오마카롱',
#  '블랙콩차',
#  '향라개구리',
#  '해장마라탄탄멘',
#  '단호박찜',
#  '고둥삼합',
#  '야마와준마이다이긴죠',
#  '헤이즐넛더블샷',
#  '엔초비파스타미트볼',
#  '화이트뱅쇼',
#  '게이샤',
#  '포천생막걸리',
#  '청포도홍차',
#  '코코넛쿠키',
#  '선지한접시',
#  '뚝배기버터콘',
#  '생부두',
#  '토핑선택하는부대찌개',
#  '한우된장',
#  '치킨스틱윙',
#  '프렌치토스트단품',
#  '산낙지데침',
#  '떡닭세트음료사이즈',
#  '새알심',
#  '수프림타코',
#  '아구찜중인분',
#  '전통족발패키지',
#  '랍무',
#  '벨지움와플',
#  '해파리냉채',
#  '오리지널버팔로윙',
#  '뽕잎차',
#  '카브루바이젠',
#  '맛보기새우장',
#  '스모',
#  '유롱차',
#  '다진생새우살',
#  '고구마카스테라다쿠아즈',
#  '핫앤스위트',
#  '타라몬티모다',
#  '모구모구',
#  '분모자',
#  '홍소가재미',
#  '콜드브루헤이즐넛라테',
#  '매운치즈불닭',
#  '숯불양념바비큐',
#  '생멸치쌈밥봄',
#  '진한매운크림떡볶이크림곱배기',
#  '민속막걸리',
#  '부채살인이상주문가능',
#  '삼겹살목살',
#  '허니통브레드카페라떼잔',
#  ...]
