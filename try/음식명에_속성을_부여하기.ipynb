# %% [markdown]
# ## 핵심 아이디어
# 1. 메뉴명을 명사 단위로 토큰화
# 2. 토큰화한 메뉴명을 빈도분석
# 3. 빈도 내림차순으로 나열한 뒤 특정 비율의 토큰을 채택
# 4. 채택한 토큰으로 끝나는 메뉴명을 토큰 카테고리로 분류
#
# ## 간단하지만 강력한 알고리즘
# 대부분 한국어 메뉴명이 분류로 종결된다는 특성을 이용하였습니다
# ex)오곡라떼 => '라떼'라는 분류명으로 종결됨
#
# 따라서 이렇게 1차 분류를 시도해보고, 오분류되었거나 미분류된 음식명을 2차 분류해보는건 어떠할지?

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 69.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.8/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from konlpy) (4.9.2)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.6/465.6 KB 35.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from JPype1>=0.7.0->konlpy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->JPype1>=0.7.0->konlpy) (3.0.9)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
# 데이터 임포팅 
df = pd.read_csv('menu_concated_v1.3')
df.dropna(inplace=True)
menu_list = df['menu'].tolist()

# %%
# 명사 단위 토큰화
from konlpy.tag import Okt
from tqdm import tqdm

t = Okt()
menu_list = [t.nouns(word) for word in tqdm(menu_list)]
# Out:
# 100%|██████████| 192332/192332 [02:09<00:00, 1489.51it/s]

# %%
# 토큰화된 리스트의 리스트 내 리스트 제거 
menu_list = [v for word in menu_list for v in word]
menu_list[:10]
# Out:
# ['정식', '짜장면', '짬뽕', '우동', '울면', '간짜장', '사천짜장', '삼선짜장', '유니짜장', '삼선']

# %%
# 토큰 빈도분석 
count_dict = {}
for i in tqdm(menu_list):
  if i not in count_dict:
    count_dict[i] = 1
  else:
    count_dict[i] += 1
# Out:
# 100%|██████████| 365109/365109 [00:00<00:00, 2004534.47it/s]

# %%
# 토큰을 빈도 내림차순으로 정렬
items = count_dict.items()
sorted_items = sorted(items, key=lambda x: x[1], reverse=True) 

# 빈도 상위 10퍼센트의 토큰만 선택
cut_line = int(len(sorted_items) / 10)

# 단, 두글자 이상인 토큰만 선택 (1글자 토큰은 결과를 곱창내놓았음;; 하지만 불용어 설정을 잘 한다면??)
outliner_vocab = [k for k, v in sorted_items[:cut_line] if len(k)!=1]
outliner_vocab[:10]
# Out:
# ['라떼', '치즈', '세트', '치킨', '추가', '맥주', '소주', '튀김', '새우', '볶음']

# %%
# 전체 메뉴명을 중복 없이 리스트로 가져옴 
menu = df['menu'].tolist()
menu = list(set(menu))
len(menu)
# Out:
# 51437

# %%
#토큰명으로 끝나는 메뉴를 토큰 카테고리로 분류!!
menu_cluster = {}

for food_token in outliner_vocab:
  for food_name in menu:
    if food_name not in menu_cluster: # 이미 분류된 메뉴는 건들지 않음

      # 메뉴명이 토큰명보다 길면서 동시에 토큰명으로 끝나는 메뉴를 토큰 카테고리로 분류 
      if len(food_token) <= len(food_name) and food_name[-len(food_token):] == food_token:
        menu_cluster[food_name] = food_token

# %%
# 분류된 메뉴를 DataFrame화 
df_menu = pd.DataFrame(columns=['title', 'category'], data=menu_cluster.items())
df_menu['category'].unique()
# Out:
# array(['라떼', '치즈', '세트', '치킨', '추가', '맥주', '소주', '튀김', '새우', '볶음', '이드',
#        '아메리카노', '피자', '구이', '스무디', '볶음밥', '불고기', '초코', '사리', '요거트', '음료수',
#        '크림', '바닐라', '자몽', '레몬', '밀크', '해물', '우동', '공기밥', '딸기', '전골',
#        '돈까스', '카라멜', '과일', '짬뽕', '라면', '정식', '샐러드', '만두', '한우', '김밥',
#        '탕수육', '양념', '고구마', '오징어', '족발', '김치', '삼겹살', '감자', '갈비', '카페모카',
#        '메뉴', '된장찌개', '떡볶이', '녹차', '막걸리', '카푸치노', '주스', '소고기', '망고',
#        '김치찌개', '돼지', '보쌈', '수육', '에스프레소', '스테이크', '파스타', '커피', '브루',
#        '아이스티', '비빔밥', '낙지', '칼국수', '전복', '블랙', '콜라', '냉면', '마끼아또', '순대',
#        '음료', '블루베리', '야채', '두부', '허니', '마늘', '오리', '참치', '간장', '민트', '등심',
#        '오뎅', '허브', '복분자', '고기', '제육', '베이컨', '얼그레이', '닭발', '스페셜', '버섯',
#        '매운탕', '고추', '초밥', '우럭', '코스', '광어', '사이다', '그린티', '바나나', '쥬스',
#        '찌개', '오렌지', '연어', '조림', '국밥', '국수', '철판', '모카', '동태', '백세주',
#        '샌드위치', '갈릭', '화이트', '토마토', '유자', '아이스', '삼선', '계란', '매콤', '마리',
#        '홍차', '잡채', '삼겹', '어묵', '물회', '해장국', '꼬치', '헤이즐넛', '생선', '버거',
#        '갈비살', '복숭아', '육회', '누룽지', '빙수', '림프', '청포도', '감자탕', '곱창', '차돌',
#        '캐모마일', '소스', '골드', '사시미', '만두국', '육개장', '플레인', '주먹밥', '포테이토',
#        '골뱅이', '카레', '리얼', '더블', '유자차', '버터', '변경', '쭈꾸미', '미니', '초콜릿',
#        '칠리', '닭볶음탕', '비빔', '갈비탕', '모듬회', '고량주', '계란찜', '냉채', '짜장', '아구찜',
#        '묵은지', '대구', '문어', '쉐이크', '차돌박이', '계란말이', '국물', '키위', '우유', '된장',
#        '카스', '해산물', '레드', '돈가스', '베리', '연태', '더치', '두루치기', '소면', '말차',
#        '코코넛', '쫄면', '해삼', '메밀', '찜닭', '블루', '뚝배기', '연유', '백숙', '버블',
#        '삼계탕', '애플', '코다리', '황태', '소세지', '클라우드', '리지', '치즈볼', '대국', '치노',
#        '도시락', '청국장', '바베큐', '고등어', '쿠키', '옛날', '직화', '눈꽃', '회덮밥', '닭도리탕',
#        '스파클링', '달고나', '화요', '수제비', '깐풍기', '해물탕', '날개', '토스트', '올리브', '부추',
#        '피치', '버블티', '다리', '카페', '머리', '생강차', '가지', '목살', '케이크', '소금',
#        '조개', '알탕', '내장', '꼬막', '갈비찜', '가라아게', '핫도그', '루이보스', '안심', '스파게티',
#        '베이글', '유기농', '백반', '곰탕', '콤보', '케익', '부대', '똥집', '허브차', '테라',
#        '아구', '마카롱', '멍게', '러스트', '송이', '짜장면', '그린', '프리미엄', '로얄', '불닭',
#        '치즈스틱', '고로케', '쟁반', '장어', '호가든', '통닭', '갈치', '능이', '고르곤졸라', '카츠',
#        '팔보채', '게살', '막창', '해물파전', '열무', '조기', '파닭', '강정', '훈제', '추어탕',
#        '매실', '가주', '모밀', '샤브', '커리', '아보카도', '바삭', '와인', '오곡', '리조또',
#        '샷추', '요리', '모짜렐라', '와플', '단호박', '명태', '명란', '숙회', '아포가토', '페퍼로니',
#        '콩나물', '히비스커스', '황도', '고추장', '시럽', '노가리', '특선', '체리', '비프', '바지락',
#        '해물찜', '땡초', '라이스', '사골', '오레오', '한치', '플랫', '아몬드', '김치전', '돌뼈',
#        '큐브', '싱글', '계절', '스팸', '배기', '케이준', '당면', '카토', '숙성', '환타', '다크',
#        '항정살', '전복죽', '브리', '비엔나', '조각', '스프', '쌈밥', '하이네켄', '마끼야또', '소시지',
#        '도미', '잡탕', '밀면', '오늘', '알밥', '어니언', '까르보나라', '참이슬', '접시', '위트',
#        '리코', '바스', '껍데기', '사천', '우거지', '스윗', '설중매', '어린이', '토핑', '그릴',
#        '로스', '머핀', '겹살', '감자전', '꼬마', '땅콩', '떡국', '무뼈', '패션후르츠', '편육',
#        '농어', '숙주', '스프라이트', '지리', '옥수수', '한판', '사케', '오미자', '월남쌈', '사이즈',
#        '칭따오', '미숫가루', '장탕', '흑임자', '인분', '콤비네이션', '티라미수', '토닉', '꽃게',
#        '라임', '포크', '술국', '쥐포', '라이', '점심', '시나몬', '가리비', '까스', '스콘',
#        '설렁탕', '하우스', '멸치', '체다', '와사비', '워터', '퍼스트', '곱빼기', '돌솥', '트리플',
#        '무한리필', '클래식', '스틱', '가자미', '곡물', '더덕', '홍합', '돌체', '울면', '바게트',
#        '생강', '인절미', '전병', '대추차', '스타', '매화수', '대패', '갈매기살', '조육', '라볶이',
#        '카모마일', '달콤', '기네스', '김말이', '이안', '트러플', '홍어', '연포탕', '자바', '소라',
#        '런치', '처음처럼', '관자', '사과', '슈프림', '모히또', '링클', '한라봉', '잉글리쉬', '루트',
#        '소바', '로우', '라멘', '드립', '자스민', '대창', '도토리묵', '설원', '치마', '석류',
#        '유부', '안주', '뼈찜', '필라프', '번데기', '돌솥밥', '방어', '선지', '하프', '한라산',
#        '식사', '도가니', '오븐', '보리', '스노우', '염통', '진로', '메기', '특수', '녹두', '타코',
#        '윙봉', '볼케이노', '국화', '바질', '생굴', '도우', '미역국', '에일', '도리', '꽃게탕',
#        '수박', '데리야끼', '대하', '뱃살', '셋트', '염소', '마을', '가복', '모듬', '매취순',
#        '메로', '간장게장', '냄비', '청주', '리치', '파이', '브라우니', '리오', '양파', '젤라또',
#        '타로', '난자완스', '하이', '도가니탕', '부위', '듬뿍', '제청', '믹스', '참돔', '뉴욕',
#        '육전', '아사히', '꽃빵', '데이', '어회', '커플', '포장', '호두', '패밀리', '껍질', '해장',
#        '후식', '피스', '라피', '퐁듀', '코코', '케냐', '하이트', '마이', '스텔라', '푸드', '박스',
#        '오이', '비지', '크러쉬', '나가사키', '고기만', '시래기', '마키아또', '청귤', '동동주',
#        '이탈리안', '디카', '페인', '식빵', '옹심이', '가시', '마루', '뽈찜', '미트', '죽엽',
#        '산미구엘', '고량', '라이트', '우롱', '로스트', '화차', '파전', '찌게', '채끝', '볶이',
#        '온면', '꼬리', '버팔로윙', '대게', '핑크', '쵸코', '차슈', '게장', '카프리', '건조',
#        '플래터', '자두', '개불', '나쵸', '버드와이저', '보드카', '발렌타인', '프레즐', '아나고',
#        '조개찜', '카레덮밥', '컵밥', '장육', '타오', '메론', '이즈', '다니엘', '식혜', '꼬시',
#        '선택', '바이트', '무스', '조니워커', '스티', '바다', '맛보기', '에티오피아', '크리미', '휘핑',
#        '탄산수', '랍스터', '과테말라', '미트볼', '일반', '황제', '추억', '북어', '슬밥', '콰트로',
#        '치아바타', '만둣국', '샥스핀', '웰치스', '착즙', '청양', '영양', '생탁', '크래커', '클럽',
#        '기본', '스시', '토종닭', '육포', '꽁치', '가스', '대만', '오미자차', '치악산', '콜롬비아',
#        '파니니', '석쇠', '헤이즐럿', '일품', '현미', '코로나', '대추', '뱅쇼', '블렌디드', '어탕',
#        '루아', '웨이브', '우육', '칵테일', '히레', '크랩', '코젤', '대선', '이크', '상차림',
#        '카라', '페페로니', '플라워', '불낙', '당근', '차이', '파티', '창살', '맥스', '사발',
#        '참치회', '찐빵', '라칸', '라스트', '노베', '비빔면', '다쿠아즈', '생선회', '멘보샤', '메리',
#        '채소', '레귤러', '나가사끼', '동파육', '라벤더', '팟타이', '라거', '석화', '깃밥', '함박',
#        '팥죽', '은행', '누텔라', '브라운슈가', '통통', '규동', '마구로', '브라운', '윙스', '핫윙',
#        '메추리', '멕시칸', '천왕', '호떡', '굴비', '쿠앤크', '또띠아', '토시', '데리', '참복',
#        '터키', '평일', '모과차', '몬스터', '퀘사디아', '위스키', '이슬', '크로와상', '도로', '홍게',
#        '베트남', '마들렌', '하와이', '스튜', '다즐링', '쟈스민', '홍어삼합', '참다랑어', '간바레',
#        '힘줄', '소이', '설빙', '폭탄', '줄돔', '수프', '국산', '딸바', '산타', '페퍼', '호박',
#        '청도', '반상', '카야', '솥밥', '홍시', '훠궈', '올갱이', '플러스', '양지', '패션', '레쉬',
#        '썸머', '돌돔', '기스면', '그라스', '리아', '아쌈', '등뼈', '불족', '링크', '가득', '리타',
#        '버그', '부채살', '프렌치', '교자', '도루묵', '오리진', '선물', '파운드', '원두', '진짜',
#        '그레이', '제비', '젤리', '크로크무슈', '쉬라즈', '하얼빈', '다슬기'], dtype=object)

# %%
pd.set_option('display.max_row', 100)

# %%
df_menu.sample(100)
# Out:
#                  title category
# 34009               채소       채소
# 26652          등심돈카츠안심       안심
# 33338           밀키베리무스       무스
# 3873         쌈야채고추마늘추가       추가
# 20385     불고기치즈그릴드샌드위치     샌드위치
# 10329              닭전골       전골
# 28744           베트남라이스      라이스
# 11739          청담순대국정식       정식
# 12380          치킨시저샐러드      샐러드
# 24373             오룡해삼       해삼
# 3571         콘치즈닭콘치즈추가       추가
# 6873          마르게리따씬피자       피자
# 6600          밤만주아메리카노    아메리카노
# 12663             흑키만두       만두
# 23198            스윗초콜릿      초콜릿
# 29799         반건조오징어땅콩       땅콩
# 33382          자가순대맛보기      맛보기
# 14659          촉촉국물떡볶이      떡볶이
# 13145             치즈김밥       김밥
# 27597              돈카츠       카츠
# 22128           치즈갈릭소스       소스
# 10629            안주돈까스      돈까스
# 20802          옛날통닭반마리       마리
# 24063         남산수제왕돈가스      돈가스
# 15557  스타셰프트러플바질직화스테이크     스테이크
# 31862           포크데리야끼     데리야끼
# 5685            직화꽃새볶음       볶음
# 3027           양념반마리치킨       치킨
# 1218              일벌세트       세트
# 24794         찹쌀고구마치즈볼      치즈볼
# 27070             미니케익       케익
# 17486             블루베리     블루베리
# 10107         칼국수보쌈공기밥      공기밥
# 29732           제주흑오겹살       겹살
# 11369            조림회정식       정식
# 11192           얼큰땡초라면       라면
# 20309       치킨샤워크림샌드위치     샌드위치
# 25650            전복해물탕      해물탕
# 21224            비엔나꼬치       꼬치
# 24218         화끈낙지두루치기     두루치기
# 21361           김치찌개생선       생선
# 8901              생불고기      불고기
# 34094             미니함박       함박
# 23999           콘치즈브레드       레드
# 27283              새송이       송이
# 22791             반반카레       카레
# 18349          비원한우스페셜      스페셜
# 21172            대창해장국      해장국
# 21177             매운꼬치       꼬치
# 31049          잉글리쉬브런치       런치
# 26959           교촌반반콤보       콤보
# 14711           후추추떡볶이      떡볶이
# 13316             허니양념       양념
# 24365               해삼       해삼
# 19027            눈꽃바나나      바나나
# 26285          레어치즈케이크      케이크
# 20580          앱솔루트화이트      화이트
# 15757          피렌체스테이크     스테이크
# 22702            윙포테이토     포테이토
# 29333            그릴소시지      소시지
# 8312     망고패션콜라겐요거트스무디      스무디
# 20991              물어묵       어묵
# 23016            파스타변경       변경
# 21627            양념갈비살      갈비살
# 12565           비비고군만두       만두
# 1485              왕벌세트       세트
# 15358             마늘보쌈       보쌈
# 16301           머핀원두커피       커피
# 10632            오무돈까스      돈까스
# 16351           수제크림커피       커피
# 26290    생딸기가득우유생크림케이크      케이크
# 33727             오징어탕       어탕
# 25885           스파클링피치       피치
# 13502           회덕반반족발       족발
# 5180              과일튀김       튀김
# 11920        하늘풍경떡갈비정식       정식
# 12461           나폴리샐러드      샐러드
# 29454          야채순대한접시       접시
# 15684         양갈비살스테이크     스테이크
# 3953              쌈밥추가       추가
# 32718           단호박팥식빵       식빵
# 1971            모듬튀김세트       세트
# 3376          냄비요리고기추가       추가
# 6661           리필아메리카노    아메리카노
# 9146           사누끼우동사리       사리
# 10806            솔티카라멜      카라멜
# 28931        우유아이스크림싱글       싱글
# 22916        아메리카노세트변경       변경
# 9136         치즈닭뽁이모듬사리       사리
# 8845           매운궁중불고기      불고기
# 8279           그린멜론스무디      스무디
# 3411            판모밀장추가       추가
# 7863              보쌈구이       구이
# 19590            통영굴국밥       국밥
# 10828            골뱅이과일       과일
# 12580           곤드레찐만두       만두
# 12072          디너스페셜정식       정식
# 22955          반마리순살변경       변경
# 7363              마늘구이       구이
# 18635             농어초밥       초밥

# %% [markdown]
# # 핵심 아이디어
# 1. 이전 토큰 종결 분류에서 계속된다
#
# 2. 특정 토큰과 가장 가까운 토큰을 몇 개 추린다
# ex) 해장국 => 뼈, 콩나물
#
# 3. 특정 토큰으로 분류된 음식명에 가까운 토큰이 포함되어 있나 조사한다
# ex) 뼈다귀 해장국 => 해장국으로 분류됨 + 뼈 토큰 포함
#
# 4. 그럼 그 음식명에 속성을 추가해준다
# ex) 뼈다귀 해장국 => 해장국 속성 + 뼈 속성
#
# 5. 두 속성이 동시에 포함된 음식명을 전체 음식 목록에서 찾는다
# ex) 해장국과 뼈가 동시에 포함된 음식명 = 뼈다귀 해장국
#
# 6. 세부 분류를 한다
# ex) 뼈해장국을 해장국 > 뼈해장국으로 분류

# %%
# 국밥을 예시로 시도해본다
df_menu[df_menu['category'] == '국밥']
# Out:
#          title category
# 19520   특미마라국밥       국밥
# 19521  시래기순대국밥       국밥
# 19522    매생이국밥       국밥
# 19523    아우내국밥       국밥
# 19524   얼큰차돌국밥       국밥
# ...        ...      ...
# 19709     선지국밥       국밥
# 19710    수구레국밥       국밥
# 19711     송이국밥       국밥
# 19712   얼큰순대국밥       국밥
# 19713      닭국밥       국밥
#
# [194 rows x 2 columns]

# %%
# 국밥 리스트 생성 
gookbab = df_menu[df_menu['category']=='국밥']['title'].tolist()
gookbab[:10]
# Out:
# ['특미마라국밥',
#  '시래기순대국밥',
#  '매생이국밥',
#  '아우내국밥',
#  '얼큰차돌국밥',
#  '순두부국밥',
#  '장터따로국밥',
#  '하노이국밥',
#  '내장섞어국밥',
#  '한우우거지국밥']

# %%
# 국밥 명사단위로 토큰화 후 리스트 내 리스트 제거 
gookbab_tokenized = [t.nouns(word) for word in gookbab]
gookbab_tokenized = [w for word in gookbab_tokenized for w in word]
gookbab_tokenized[:10]
# Out:
# ['특', '국밥', '시래기', '순대', '국밥', '생', '국밥', '아우', '국밥', '얼']

# %%
# 토큰화된 국밥 리스트 분석
import nltk
gookbab_ko = nltk.Text(gookbab_tokenized, name='국밥 토큰')

# %%
# 국밥 토큰 개수와 빈도 분석 
gookbab_similar = gookbab_ko.vocab().most_common(15)
len(gookbab_ko), gookbab_similar
# Out:
# (446,
#  [('국밥', 164),
#   ('순대', 19),
#   ('콩나물', 18),
#   ('얼', 15),
#   ('한우', 9),
#   ('소고기', 9),
#   ('장터', 8),
#   ('굴국밥', 8),
#   ('김치', 7),
#   ('장국밥', 7),
#   ('돼지국밥', 7),
#   ('시래기', 5),
#   ('우거지', 5),
#   ('고기', 5),
#   ('소머리국밥', 5)])

# %%
# 국밥 종류 생성
kind_of_gookbab = [value for value, num in gookbab_similar if len(value) != 1]
kind_of_gookbab
# Out:
# ['국밥',
#  '순대',
#  '콩나물',
#  '한우',
#  '소고기',
#  '장터',
#  '굴국밥',
#  '김치',
#  '장국밥',
#  '돼지국밥',
#  '시래기',
#  '우거지',
#  '고기',
#  '소머리국밥']

# %%
for token in kind_of_gookbab[1:]: #kind_of_gookbab[0] = '국밥'
  for menu in gookbab:
    if token in menu:
      print(f'{menu}: {token}')
# Out:
# 시래기순대국밥: 순대
# 부산순대국밥: 순대
# 순대고기국밥: 순대
# 순대국밥: 순대
# 매운고추순대국밥: 순대
# 순대만국밥: 순대
# 김치순대국밥: 순대
# 따로순대국밥: 순대
# 순대뽈살국밥: 순대
# 올순대국밥: 순대
# 토종순대국밥: 순대
# 우거지순대국밥: 순대
# 황태순대국밥: 순대
# 콩나물순대국밥: 순대
# 특매운순대국밥: 순대
# 찰순대국밥: 순대
# 순대지옥국밥: 순대
# 얼큰장순대국밥: 순대
# 사골순대국밥: 순대
# 고기순대섞어국밥: 순대
# 흰순대국밥: 순대
# 한우사골순대국밥: 순대
# 얼큰이순대국밥: 순대
# 매운순대국밥: 순대
# 특순대국밥: 순대
# 순대국국밥: 순대
# 장순대국밥: 순대
# 살고기순대국밥: 순대
# 순대섞어국밥: 순대
# 얼큰순대국밥: 순대
# 양지콩나물국밥: 콩나물
# 김치콩나물따로국밥: 콩나물
# 콩나물김치국밥: 콩나물
# 한우콩나물국밥: 콩나물
# 불고기콩나물국밥: 콩나물
# 황태콩나물국밥: 콩나물
# 전주콩나물국밥: 콩나물
# 콩나물따로국밥: 콩나물
# 콩나물순대국밥: 콩나물
# 어린이콩나물국밥: 콩나물
# 전주식콩나물국밥: 콩나물
# 김치콩나물국밥: 콩나물
# 굴콩나물국밥: 콩나물
# 콩나물국밥: 콩나물
# 따로굴콩나물국밥: 콩나물
# 전주끊이는식콩나물국밥: 콩나물
# 전주남부시장식콩나물국밥: 콩나물
# 콩나물황태해장국밥: 콩나물
# 한우우거지국밥: 한우
# 한우콩나물국밥: 한우
# 한우장국밥: 한우
# 한우소머리국밥: 한우
# 한우소국밥: 한우
# 한우사골순대국밥: 한우
# 한우장터국밥: 한우
# 한우얼큰소머리국밥: 한우
# 한우따로국밥: 한우
# 한우시골장터국밥: 한우
# 한우국밥: 한우
# 구월산소고기국밥: 소고기
# 얼큰소고기국밥: 소고기
# 소고기국밥: 소고기
# 연변소고기국밥: 소고기
# 소고기따로국밥: 소고기
# 장터소고기국밥: 소고기
# 양평소고기국밥: 소고기
# 한끼소고기국밥: 소고기
# 얼큰소고기가마솥국밥: 소고기
# 장터따로국밥: 장터
# 소뼈장터국밥: 장터
# 한우장터국밥: 장터
# 장터소고기국밥: 장터
# 장터국밥: 장터
# 한우시골장터국밥: 장터
# 시골장터국밥: 장터
# 장터소국밥: 장터
# 들깨굴국밥: 굴국밥
# 하얀굴국밥: 굴국밥
# 따로매생이굴국밥: 굴국밥
# 굴국밥: 굴국밥
# 매생이굴국밥: 굴국밥
# 통영굴국밥: 굴국밥
# 얼큰굴국밥: 굴국밥
# 따로굴국밥: 굴국밥
# 김치콩나물따로국밥: 김치
# 콩나물김치국밥: 김치
# 김치순대국밥: 김치
# 김치콩나물국밥: 김치
# 거창에서즐겨먹던김치국밥: 김치
# 김치국밥: 김치
# 김치따로국밥: 김치
# 일품내장국밥: 장국밥
# 시래기된장국밥: 장국밥
# 한우장국밥: 장국밥
# 수원고기집된장국밥: 장국밥
# 올내장국밥: 장국밥
# 쇠고기장국밥: 장국밥
# 따로내장국밥: 장국밥
# 내장국밥: 장국밥
# 다슬기장국밥: 장국밥
# 사골우거지된장국밥: 장국밥
# 콩나물황태해장국밥: 장국밥
# 돼지국밥: 돼지국밥
# 꿀돼지국밥: 돼지국밥
# 따로돼지국밥: 돼지국밥
# 부산돼지국밥: 돼지국밥
# 극상돼지국밥: 돼지국밥
# 시래기돼지국밥: 돼지국밥
# 얼큰돼지국밥: 돼지국밥
# 시래기순대국밥: 시래기
# 시래기된장국밥: 시래기
# 시래기따로국밥: 시래기
# 시래기국밥: 시래기
# 시래기돼지국밥: 시래기
# 한우우거지국밥: 우거지
# 얼큰우거지국밥: 우거지
# 우거지순대국밥: 우거지
# 우거지국밥: 우거지
# 사골우거지된장국밥: 우거지
# 순대고기국밥: 고기
# 구월산소고기국밥: 고기
# 얼큰소고기국밥: 고기
# 고기내장섞어국밥: 고기
# 소고기국밥: 고기
# 얼큰고기국밥: 고기
# 불고기콩나물국밥: 고기
# 수원고기집된장국밥: 고기
# 고기국밥: 고기
# 쇠고기장국밥: 고기
# 연변소고기국밥: 고기
# 고기순대섞어국밥: 고기
# 사골고기국밥: 고기
# 살고기국밥: 고기
# 돼지고기국밥: 고기
# 소고기따로국밥: 고기
# 장터소고기국밥: 고기
# 양평소고기국밥: 고기
# 머릿고기국밥: 고기
# 한끼소고기국밥: 고기
# 얼큰소고기가마솥국밥: 고기
# 살고기순대국밥: 고기
# 쇠고기국밥: 고기
# 소머리국밥: 소머리국밥
# 곤지암소머리국밥: 소머리국밥
# 한우소머리국밥: 소머리국밥
# 가마솥소머리국밥: 소머리국밥
# 한우얼큰소머리국밥: 소머리국밥
